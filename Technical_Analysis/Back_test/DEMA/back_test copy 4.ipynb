# %%
import pandas as pd
import numpy as np
from binance.client import Client
import warnings
warnings.simplefilter(action='ignore', category=FutureWarning)
pd.options.mode.chained_assignment = None

# %%
class Strategy():
    def __init__(self, client, symbols, timeframe, startdate = "2 year ago UTC", service_charge = 0.00075, money = 1000, storage = 0):
        self.client = client
        self.symbols = symbols
        self.timeframe = timeframe
        self.startdate = startdate
        self.service_charge = service_charge
        self.start_money = [money] * len(symbols)
        self.start_storage = [storage] * len(symbols)

        self.all_data = []
        for coin in symbols:
            bars = client.get_historical_klines(symbol=f'{coin}USDT',interval=timeframe,start_str=self.startdate)
            test_df = pd.DataFrame(bars[:],columns=["timestamp","open","high","low","close","volume", "close_time", "quote_asset_volume", "number_of_trade", "TBB", "TBQ", "ignore"])
            test_df["date"]=pd.to_datetime(test_df["timestamp"],unit="ms").astype(str)
            test_df = test_df.drop(["timestamp", "close_time", "quote_asset_volume", "number_of_trade", "TBB", "TBQ", "ignore"], axis=1)
            test_df["open"] = pd.to_numeric(test_df["open"])
            test_df["high"] = pd.to_numeric(test_df["high"])
            test_df["low"] = pd.to_numeric(test_df["low"])
            test_df["close"] = pd.to_numeric(test_df["close"])
            test_df["volume"] = pd.to_numeric(test_df["volume"])
            test_df["signal"] = ["None"] * len(test_df)
            self.all_data.append(test_df)

        self.profit = [0] * len(symbols)
    def print(self):
        print("Time frame", self.timeframe)
        print("Start from", self.startdate)

        for i in range(len(self.symbols)):
            print("=============")
            print(self.symbols[i], self.profit[i])

        print("=============")
        print("average", sum(self.profit) / len(self.profit))

    def decide_action(self):
        pass

    def back_test(self, type = "all in", fixed_money = None):
        for i in range(len(self.symbols)):
            money = self.start_money[i]
            storage = self.start_storage[i]
            for j in range(len(self.all_data[i])):
                if (self.all_data[i]["signal"][j] == "buy"):
                    if (type == "all in"):
                        if (storage < 0):
                            money -= -1 * storage * self.all_data[i]["close"][j]
                            storage = 0
                        storage += money / self.all_data[i]["close"][j] 
                        money = 0
                    else:
                        if (storage > 0):
                            money -= -1 * storage * self.all_data[i]["close"][j]
                            storage = 0
                        storage += fixed_money[i] / self.all_data[i]["close"][j] 
                        money -= fixed_money[i]
                elif (self.all_data[i]["signal"][j] == "sell"):
                    if (type == "all in"):
                        if (storage > 0):
                            money += storage * self.all_data[i]["close"][j]
                            storage = 0
                        storage -= money / self.all_data[i]["close"][j] 
                        money += money
                    else:
                        if (storage > 0):
                            money += storage * self.all_data[i]["close"][j]
                            storage = 0
                        storage -= fixed_money[i] / self.all_data[i]["close"][j] 
                        money += fixed_money[i]
            self.profit[i] = (money + storage * self.all_data[i]["close"][len(self.all_data[i]) - 1]) / self.start_money[i]

# %%
class EMA(Strategy):
    def decide_action(self, smooth = 2, short_period = 10, long_period = 100, stable_offset = 150):
        for i in range(len(self.all_data)):
            self.all_data[i]["short EMA"] = self.all_data[i]["close"].copy()
            self.all_data[i]["long EMA"] = self.all_data[i]["close"].copy()

            for j in range(1, len(self.all_data[i])):
                self.all_data[i]["short EMA"][j] = self.all_data[i]["short EMA"][j] * smooth / (short_period + 1) + self.all_data[i]["short EMA"][j - 1] * (1 - smooth / (short_period + 1))
                self.all_data[i]["long EMA"][j] = self.all_data[i]["long EMA"][j] * smooth / (long_period + 1) + self.all_data[i]["long EMA"][j - 1] * (1 - smooth / (long_period + 1))
            for j in range(stable_offset, len(self.all_data[i])):
                if (self.all_data[i]["short EMA"][j - 1] > self.all_data[i]["long EMA"][j - 1] and self.all_data[i]["short EMA"][j - 2] < self.all_data[i]["long EMA"][j - 2]):
                    self.all_data[i]["signal"][j] = "buy"
                elif (self.all_data[i]["short EMA"][j - 1] < self.all_data[i]["long EMA"][j - 1] and self.all_data[i]["short EMA"][j - 2] > self.all_data[i]["long EMA"][j - 2]):
                    self.all_data[i]["signal"][j] = "sell"

# %%
profits = []
count = 0
target_symbol = ["BTC", "ETH", "ADA", "BNB"]
time_frames = ["1d", "12h", "6h", "4h", "2h", "1h"]
time_frames = ["2h"]
start_str = "1 year ago UTC"
client = Client("YjY0w2BJZZ35o2Q9So1OvRP1gm3exc01LKp2yyLpMth5xmqVn0tQosRYOPrnb7la", "5rRXJ2rOa96hVPZTTOfVP9H4blP6AMt2QN2M0RWX2cMq9PngbJ5MEK88eGB9I4YD")
res = []
for timeframe in time_frames:
    for short_period in range(10, 25):
        for long_period in range(90,120):
            a = EMA(client, target_symbol, timeframe, start_str)
            a.decide_action(short_period=short_period, long_period=long_period)
            a.back_test(type="all in")
            res.append([short_period, long_period, timeframe, sum(a.profit) / len(a.profit)])
            print("short", short_period, "long", long_period, "timeframe", timeframe, "average", sum(a.profit) / len(a.profit))
# Out:
# short 10 long 90 timeframe 2h average 2.230942554975113
# short 10 long 91 timeframe 2h average 2.2674184459273232
# short 10 long 92 timeframe 2h average 2.318245515475829
# short 10 long 93 timeframe 2h average 2.141408999435176
# short 10 long 94 timeframe 2h average 2.192384645894186
# short 10 long 95 timeframe 2h average 2.3377073260789123
# short 10 long 96 timeframe 2h average 2.56789715460574
# short 10 long 97 timeframe 2h average 2.32351751801893
# short 10 long 98 timeframe 2h average 2.3000272964498385
# short 10 long 99 timeframe 2h average 2.2687974216685722
# short 10 long 100 timeframe 2h average 2.2725233971457617
# short 10 long 101 timeframe 2h average 2.0550959138355123
# short 10 long 102 timeframe 2h average 2.12518675499713
# short 10 long 103 timeframe 2h average 2.118371163893151
# short 10 long 104 timeframe 2h average 2.071170875706455
# short 10 long 105 timeframe 2h average 2.1054611693965857
# short 10 long 106 timeframe 2h average 2.1286665253815364
# short 10 long 107 timeframe 2h average 2.1407774015745833
# short 10 long 108 timeframe 2h average 2.276127327472631
# short 10 long 109 timeframe 2h average 2.179561638098621
# short 10 long 110 timeframe 2h average 2.2756814179022227
# short 10 long 111 timeframe 2h average 2.1740261172334483
# short 10 long 112 timeframe 2h average 2.166055548632681
# short 10 long 113 timeframe 2h average 2.204701434910526
# short 10 long 114 timeframe 2h average 2.1165749741540654
# short 10 long 115 timeframe 2h average 2.0687019258955526
# short 10 long 116 timeframe 2h average 2.2094398301199196
# short 10 long 117 timeframe 2h average 2.2803185798322287
# short 18 long 107 timeframe 2h average 1.855636545235578
# short 18 long 108 timeframe 2h average 1.8612107094730663
# short 18 long 109 timeframe 2h average 1.911826415423462
# short 18 long 110 timeframe 2h average 1.8554696357914553
# short 18 long 111 timeframe 2h average 1.8440891807983446
# short 18 long 112 timeframe 2h average 1.9286039800365942
# short 18 long 113 timeframe 2h average 1.9392490810162766
# short 18 long 114 timeframe 2h average 1.9449969777674128
# short 18 long 115 timeframe 2h average 1.9003474587638258
# short 18 long 116 timeframe 2h average 1.8775160795924382
# short 18 long 117 timeframe 2h average 1.9199958922706846
# short 18 long 118 timeframe 2h average 1.9573790464004452
# short 18 long 119 timeframe 2h average 2.0039678838781536
# short 19 long 90 timeframe 2h average 2.1462112992401803
# short 19 long 91 timeframe 2h average 2.27159196836372
# short 19 long 92 timeframe 2h average 2.324717115704874
# short 19 long 93 timeframe 2h average 2.2898088999095907
# short 19 long 94 timeframe 2h average 2.493417499260987
# short 19 long 95 timeframe 2h average 2.5306894740725108
# short 19 long 96 timeframe 2h average 2.3882380333207185
# short 19 long 97 timeframe 2h average 2.241813162612881
# short 19 long 98 timeframe 2h average 2.190405346668864
# short 19 long 99 timeframe 2h average 2.2308688223476745
# short 19 long 100 timeframe 2h average 2.08230990801557
# short 19 long 101 timeframe 2h average 2.0126062420961586
# short 19 long 102 timeframe 2h average 2.0044768308970986
# short 19 long 103 timeframe 2h average 1.9160503894409588
# short 19 long 104 timeframe 2h average 1.90782005741818
# short 19 long 105 timeframe 2h average 1.9147905258386535
# short 19 long 106 timeframe 2h average 1.8382420544397018
# short 19 long 107 timeframe 2h average 1.8222053496015382
# short 19 long 108 timeframe 2h average 1.8125339975320887
# short 19 long 109 timeframe 2h average 1.8120851701817569
# short 19 long 110 timeframe 2h average 1.8720460581128282
# short 19 long 111 timeframe 2h average 1.9048103720818004
# short 19 long 112 timeframe 2h average 1.9788602068326089
# short 19 long 113 timeframe 2h average 1.9164026014095314
# short 19 long 114 timeframe 2h average 1.8969731394114089
# short 19 long 115 timeframe 2h average 1.9179115887584475
# short 19 long 116 timeframe 2h average 1.9025358351402901
# short 19 long 117 timeframe 2h average 1.9065734885042
# short 19 long 118 timeframe 2h average 1.901026327990133
# short 19 long 119 timeframe 2h average 1.9095084258716175
# short 20 long 90 timeframe 2h average 2.3559425652087818
# short 20 long 91 timeframe 2h average 2.3580508362588533
# short 20 long 92 timeframe 2h average 2.4127009551604077
# short 20 long 93 timeframe 2h average 2.3338896517590237
# short 20 long 94 timeframe 2h average 2.184312518716853
# short 20 long 95 timeframe 2h average 2.1161518240442283
# short 20 long 96 timeframe 2h average 2.1528679325880096
# short 20 long 97 timeframe 2h average 2.2052955577244795
# short 20 long 98 timeframe 2h average 2.0809688604739334

# %%
a.print()
# Out:
# Time frame 12h
# Start from 2 year ago UTC
# =============
# BTC 4.056921398629486
# =============
# ETH 13.624799470601852
# =============
# ADA 27.3147432338424
# =============
# BNB 21.774236596878115
# =============
# average 16.69267517498796
