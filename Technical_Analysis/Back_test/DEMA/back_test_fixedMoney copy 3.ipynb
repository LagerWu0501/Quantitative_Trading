# %%
import pandas as pd
import numpy as np
from binance.client import Client
import warnings
warnings.simplefilter(action='ignore', category=FutureWarning)
pd.options.mode.chained_assignment = None

# %%
class Strategy():
    def __init__(self, client, symbols, timeframe, startdate = "2 year ago UTC", service_charge = 0.00075, money = 1000, storage = 0):
        self.client = client
        self.symbols = symbols
        self.timeframe = timeframe
        self.startdate = startdate
        self.service_charge = service_charge
        self.start_money = [money] * len(symbols)
        self.start_storage = [storage] * len(symbols)

        self.all_data = []
        for coin in symbols:
            bars = client.get_historical_klines(symbol=f'{coin}USDT',interval=timeframe,start_str=self.startdate)
            test_df = pd.DataFrame(bars[:],columns=["timestamp","open","high","low","close","volume", "close_time", "quote_asset_volume", "number_of_trade", "TBB", "TBQ", "ignore"])
            test_df["date"]=pd.to_datetime(test_df["timestamp"],unit="ms").astype(str)
            test_df = test_df.drop(["timestamp", "close_time", "quote_asset_volume", "number_of_trade", "TBB", "TBQ", "ignore"], axis=1)
            test_df["open"] = pd.to_numeric(test_df["open"])
            test_df["high"] = pd.to_numeric(test_df["high"])
            test_df["low"] = pd.to_numeric(test_df["low"])
            test_df["close"] = pd.to_numeric(test_df["close"])
            test_df["volume"] = pd.to_numeric(test_df["volume"])
            test_df["signal"] = ["None"] * len(test_df)
            self.all_data.append(test_df)

        self.profit = [0] * len(symbols)
    def print(self):
        print("Time frame", self.timeframe)
        print("Start from", self.startdate)

        for i in range(len(self.symbols)):
            print("=============")
            print(self.symbols[i], self.profit[i])

        print("=============")
        print("average", sum(self.profit) / len(self.profit))

    def decide_action(self):
        pass

    def back_test(self, type = "all in", fixed_money = None):
        for i in range(len(self.symbols)):
            money = self.start_money[i]
            storage = self.start_storage[i]
            for j in range(len(self.all_data[i])):
                if (self.all_data[i]["signal"][j] == "buy"):
                    if (type == "all in"):
                        if (storage < 0):
                            money -= -1 * storage * self.all_data[i]["close"][j]
                            storage = 0
                        storage += money / self.all_data[i]["close"][j] 
                        money = 0
                    else:
                        if (storage > 0):
                            money -= -1 * storage * self.all_data[i]["close"][j]
                            storage = 0
                        storage += fixed_money[i] / self.all_data[i]["close"][j] 
                        money -= fixed_money[i]
                elif (self.all_data[i]["signal"][j] == "sell"):
                    if (type == "all in"):
                        if (storage > 0):
                            money += storage * self.all_data[i]["close"][j]
                            storage = 0
                        storage -= money / self.all_data[i]["close"][j] 
                        money += money
                    else:
                        if (storage > 0):
                            money += storage * self.all_data[i]["close"][j]
                            storage = 0
                        storage -= fixed_money[i] / self.all_data[i]["close"][j] 
                        money += fixed_money[i]
            self.profit[i] = (money + storage * self.all_data[i]["close"][len(self.all_data[i]) - 1]) / self.start_money[i]

# %%
class EMA(Strategy):
    def decide_action(self, smooth = 2, short_period = 10, long_period = 100, stable_offset = 150):
        for i in range(len(self.all_data)):
            self.all_data[i]["short EMA"] = self.all_data[i]["close"].copy()
            self.all_data[i]["long EMA"] = self.all_data[i]["close"].copy()

            for j in range(1, len(self.all_data[i])):
                self.all_data[i]["short EMA"][j] = self.all_data[i]["short EMA"][j] * smooth / (short_period + 1) + self.all_data[i]["short EMA"][j - 1] * (1 - smooth / (short_period + 1))
                self.all_data[i]["long EMA"][j] = self.all_data[i]["long EMA"][j] * smooth / (long_period + 1) + self.all_data[i]["long EMA"][j - 1] * (1 - smooth / (long_period + 1))
            for j in range(stable_offset, len(self.all_data[i])):
                if (self.all_data[i]["short EMA"][j - 1] > self.all_data[i]["long EMA"][j - 1] and self.all_data[i]["short EMA"][j - 2] < self.all_data[i]["long EMA"][j - 2]):
                    self.all_data[i]["signal"][j] = "buy"
                elif (self.all_data[i]["short EMA"][j - 1] < self.all_data[i]["long EMA"][j - 1] and self.all_data[i]["short EMA"][j - 2] > self.all_data[i]["long EMA"][j - 2]):
                    self.all_data[i]["signal"][j] = "sell"

# %%
profits = []
count = 0
target_symbol = ["BTC", "ETH", "ADA", "BNB"]
time_frames = ["1d", "12h", "6h", "4h", "2h", "1h"]
time_frames = ["2h"]
start_str = "1 year ago UTC"
client = Client("", "")
res = []
for timeframe in time_frames:
    for short_period in range(13, 17):
        for long_period in range(95,111):
            a = EMA(client, target_symbol, timeframe, start_str)
            b = EMA(client, target_symbol, timeframe, start_str)
            a.decide_action(short_period=short_period, long_period=long_period)
            b.decide_action(short_period=short_period, long_period=long_period)
            a.back_test(type="fixed_money", fixed_money=[1000] * len(target_symbol))
            b.back_test(type="all in", fixed_money=[1000] * len(target_symbol))
            res.append([short_period, long_period, timeframe, sum(a.profit) / len(a.profit)])
            print("short", short_period, "long", long_period, "timeframe", timeframe, "average","fixed money", sum(a.profit) / len(a.profit), "all in", sum(b.profit) / len(b.profit))
# Out:
# short 13 long 95 timeframe 2h average fixed money 1.7694674983967624 all in 1.9318807709125723
# short 13 long 96 timeframe 2h average fixed money 1.7741823673724066 all in 1.9461702848371272
# short 13 long 97 timeframe 2h average fixed money 1.7665470263029197 all in 1.9270694199918548
# short 13 long 98 timeframe 2h average fixed money 1.7727667303694579 all in 1.9722664295496535
# short 13 long 99 timeframe 2h average fixed money 1.7769267021056387 all in 1.9223977768255023
# short 13 long 100 timeframe 2h average fixed money 1.7800774952539553 all in 2.0271102820502573
# short 13 long 101 timeframe 2h average fixed money 1.781982023095477 all in 2.020745122039653
# short 13 long 102 timeframe 2h average fixed money 1.793239283690419 all in 2.0723538384538593
# short 13 long 103 timeframe 2h average fixed money 1.7855811316436747 all in 2.065144545786755
# short 13 long 104 timeframe 2h average fixed money 1.8098937949239486 all in 2.1529636795179803
# short 13 long 105 timeframe 2h average fixed money 1.8196057927373561 all in 2.2402951739731907
# short 13 long 106 timeframe 2h average fixed money 1.8034549460684812 all in 2.186254455037418
# short 13 long 107 timeframe 2h average fixed money 1.8155635449431793 all in 2.2205178084315227
# short 13 long 108 timeframe 2h average fixed money 1.8084767645691973 all in 2.184923917807349
# short 13 long 109 timeframe 2h average fixed money 2.1320928812209488 all in 2.1295860901602914
# short 13 long 110 timeframe 2h average fixed money 2.137928875253053 all in 2.214730275035827
# short 14 long 95 timeframe 2h average fixed money 1.7952014498787192 all in 1.999476226409719
# short 14 long 96 timeframe 2h average fixed money 1.7891900822227347 all in 2.0227532410462206
# short 14 long 97 timeframe 2h average fixed money 1.786611044804247 all in 2.0209112634923057
# short 14 long 98 timeframe 2h average fixed money 1.7937676273538603 all in 2.062900417219625
# short 14 long 99 timeframe 2h average fixed money 1.7988813177090672 all in 2.1232704010512093
# short 14 long 100 timeframe 2h average fixed money 1.7997067331879786 all in 2.1141027740940443
# short 14 long 101 timeframe 2h average fixed money 1.788231814673589 all in 2.0841067952745442
# short 14 long 102 timeframe 2h average fixed money 1.808033296368562 all in 2.179183406833773
# short 14 long 103 timeframe 2h average fixed money 1.8080189148536028 all in 2.17279092902904
# short 14 long 104 timeframe 2h average fixed money 1.8103213023367526 all in 2.1545057206739537
# short 14 long 105 timeframe 2h average fixed money 1.8175612127371898 all in 2.228776092454828
# short 14 long 106 timeframe 2h average fixed money 1.8265893681237755 all in 2.3675185598728934
# short 14 long 107 timeframe 2h average fixed money 2.165744220475946 all in 2.311219636939918
# short 14 long 108 timeframe 2h average fixed money 2.138706410818437 all in 2.185110789467279
# short 14 long 109 timeframe 2h average fixed money 2.1500963783213045 all in 2.243757181989878
# short 14 long 110 timeframe 2h average fixed money 2.1370554672146294 all in 2.173797777085625
# short 15 long 95 timeframe 2h average fixed money 1.7879222675219122 all in 2.030647240978341
# short 15 long 96 timeframe 2h average fixed money 1.7972132121143312 all in 2.040200136806647
# short 15 long 97 timeframe 2h average fixed money 1.7903918415516757 all in 2.0320651635639715
# short 15 long 98 timeframe 2h average fixed money 1.8006914767763142 all in 2.098205858484682
# short 15 long 99 timeframe 2h average fixed money 1.8068573942222725 all in 2.1768465063674975
# short 15 long 100 timeframe 2h average fixed money 1.8011700943263877 all in 2.1588035326081716
# short 15 long 101 timeframe 2h average fixed money 1.820224114177317 all in 2.330140045388714
# short 15 long 102 timeframe 2h average fixed money 1.822902071535966 all in 2.402042426474863
# short 15 long 103 timeframe 2h average fixed money 1.813412437603315 all in 2.2725887448487057
# short 15 long 104 timeframe 2h average fixed money 2.162594997235481 all in 2.3284076398422857
# short 15 long 105 timeframe 2h average fixed money 2.17114869567091 all in 2.300215549649531
# short 15 long 106 timeframe 2h average fixed money 2.149286973061833 all in 2.306830271924609
# short 15 long 107 timeframe 2h average fixed money 2.1552253169299975 all in 2.3544926978699845
# short 15 long 108 timeframe 2h average fixed money 2.1420352045106594 all in 2.3620325032249676
# short 15 long 109 timeframe 2h average fixed money 2.118224284237118 all in 2.246964846600999
# short 15 long 110 timeframe 2h average fixed money 2.114401810239438 all in 2.174983994982978
# short 16 long 95 timeframe 2h average fixed money 1.802347507936739 all in 2.106238827888282
# short 16 long 96 timeframe 2h average fixed money 1.7971911732802694 all in 2.150578682911202
# short 16 long 97 timeframe 2h average fixed money 1.8021767887438562 all in 2.269412546100323
# short 16 long 98 timeframe 2h average fixed money 1.8090421871877325 all in 2.28693816628951
# short 16 long 99 timeframe 2h average fixed money 1.824909306504143 all in 2.379899716433042
# short 16 long 100 timeframe 2h average fixed money 1.79978475980444 all in 2.2296954686489356
# short 16 long 101 timeframe 2h average fixed money 2.1727593968932823 all in 2.3425421761804337
# short 16 long 102 timeframe 2h average fixed money 2.1941299687335665 all in 2.6210741447977592
# short 16 long 103 timeframe 2h average fixed money 2.180756717938386 all in 2.4691739906288332
# short 16 long 104 timeframe 2h average fixed money 2.142850873026989 all in 2.2964846472079894
# short 16 long 105 timeframe 2h average fixed money 2.1326165738693645 all in 2.2559886042554056
# short 16 long 106 timeframe 2h average fixed money 2.1418974879004833 all in 2.2382685583629853
# short 16 long 107 timeframe 2h average fixed money 2.1282367639291353 all in 2.1463926215796953
# short 16 long 108 timeframe 2h average fixed money 2.103633604444257 all in 2.108900819908958
# short 16 long 109 timeframe 2h average fixed money 2.0999430180239003 all in 2.0540598494551188
# short 16 long 110 timeframe 2h average fixed money 2.11536258357567 all in 2.0537284463705037

# %%
a.print()
# Out:
# Time frame 4h
# Start from 1 year ago UTC
# =============
# BTC 1.6081742224918552
# =============
# ETH 1.6146974156193237
# =============
# ADA 2.8022614494269473
# =============
# BNB 1.6174743712053914
# =============
# average 1.9106518646858794
