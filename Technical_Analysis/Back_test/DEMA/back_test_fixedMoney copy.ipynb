# %%
import pandas as pd
import numpy as np
from binance.client import Client
import warnings
warnings.simplefilter(action='ignore', category=FutureWarning)
pd.options.mode.chained_assignment = None

# %%
class Strategy():
    def __init__(self, client, symbols, timeframe, startdate = "2 year ago UTC", service_charge = 0.00075, money = 1000, storage = 0):
        self.client = client
        self.symbols = symbols
        self.timeframe = timeframe
        self.startdate = startdate
        self.service_charge = service_charge
        self.start_money = [money] * len(symbols)
        self.start_storage = [storage] * len(symbols)

        self.all_data = []
        for coin in symbols:
            bars = client.get_historical_klines(symbol=f'{coin}USDT',interval=timeframe,start_str=self.startdate)
            test_df = pd.DataFrame(bars[:],columns=["timestamp","open","high","low","close","volume", "close_time", "quote_asset_volume", "number_of_trade", "TBB", "TBQ", "ignore"])
            test_df["date"]=pd.to_datetime(test_df["timestamp"],unit="ms").astype(str)
            test_df = test_df.drop(["timestamp", "close_time", "quote_asset_volume", "number_of_trade", "TBB", "TBQ", "ignore"], axis=1)
            test_df["open"] = pd.to_numeric(test_df["open"])
            test_df["high"] = pd.to_numeric(test_df["high"])
            test_df["low"] = pd.to_numeric(test_df["low"])
            test_df["close"] = pd.to_numeric(test_df["close"])
            test_df["volume"] = pd.to_numeric(test_df["volume"])
            test_df["signal"] = ["None"] * len(test_df)
            self.all_data.append(test_df)

        self.profit = [0] * len(symbols)
    def print(self):
        print("Time frame", self.timeframe)
        print("Start from", self.startdate)

        for i in range(len(self.symbols)):
            print("=============")
            print(self.symbols[i], self.profit[i])

        print("=============")
        print("average", sum(self.profit) / len(self.profit))

    def decide_action(self):
        pass

    def back_test(self, type = "all in", fixed_money = None):
        for i in range(len(self.symbols)):
            money = self.start_money[i]
            storage = self.start_storage[i]
            for j in range(len(self.all_data[i])):
                if (self.all_data[i]["signal"][j] == "buy"):
                    if (type == "all in"):
                        if (storage < 0):
                            money -= -1 * storage * self.all_data[i]["close"][j]
                            storage = 0
                        storage += money / self.all_data[i]["close"][j] 
                        money = 0
                    else:
                        if (storage > 0):
                            money -= -1 * storage * self.all_data[i]["close"][j]
                            storage = 0
                        storage += fixed_money[i] / self.all_data[i]["close"][j] 
                        money -= fixed_money[i]
                elif (self.all_data[i]["signal"][j] == "sell"):
                    if (type == "all in"):
                        if (storage > 0):
                            money += storage * self.all_data[i]["close"][j]
                            storage = 0
                        storage -= money / self.all_data[i]["close"][j] 
                        money += money
                    else:
                        if (storage > 0):
                            money += storage * self.all_data[i]["close"][j]
                            storage = 0
                        storage -= fixed_money[i] / self.all_data[i]["close"][j] 
                        money += fixed_money[i]
            self.profit[i] = (money + storage * self.all_data[i]["close"][len(self.all_data[i]) - 1]) / self.start_money[i]

# %%
class EMA(Strategy):
    def decide_action(self, smooth = 2, short_period = 10, long_period = 100, stable_offset = 150):
        for i in range(len(self.all_data)):
            self.all_data[i]["short EMA"] = self.all_data[i]["close"].copy()
            self.all_data[i]["long EMA"] = self.all_data[i]["close"].copy()

            for j in range(1, len(self.all_data[i])):
                self.all_data[i]["short EMA"][j] = self.all_data[i]["short EMA"][j] * smooth / (short_period + 1) + self.all_data[i]["short EMA"][j - 1] * (1 - smooth / (short_period + 1))
                self.all_data[i]["long EMA"][j] = self.all_data[i]["long EMA"][j] * smooth / (long_period + 1) + self.all_data[i]["long EMA"][j - 1] * (1 - smooth / (long_period + 1))
            for j in range(stable_offset, len(self.all_data[i])):
                if (self.all_data[i]["short EMA"][j - 1] > self.all_data[i]["long EMA"][j - 1] and self.all_data[i]["short EMA"][j - 2] < self.all_data[i]["long EMA"][j - 2]):
                    self.all_data[i]["signal"][j] = "buy"
                elif (self.all_data[i]["short EMA"][j - 1] < self.all_data[i]["long EMA"][j - 1] and self.all_data[i]["short EMA"][j - 2] > self.all_data[i]["long EMA"][j - 2]):
                    self.all_data[i]["signal"][j] = "sell"

# %%
profits = []
count = 0
target_symbol = ["BTC", "ETH", "ADA", "BNB"]
time_frames = ["1d", "12h", "6h", "4h", "2h", "1h"]
time_frames = ["12h"]
start_str = "1 year ago UTC"
client = Client("", "")
res = []
for timeframe in time_frames:
    for short_period in range(13, 17):
        for long_period in range(95,111):
            a = EMA(client, target_symbol, timeframe, start_str)
            b = EMA(client, target_symbol, timeframe, start_str)
            a.decide_action(short_period=short_period, long_period=long_period)
            b.decide_action(short_period=short_period, long_period=long_period)
            a.back_test(type="fixed_money", fixed_money=[1000] * len(target_symbol))
            b.back_test(type="all in", fixed_money=[1000] * len(target_symbol))
            res.append([short_period, long_period, timeframe, sum(a.profit) / len(a.profit)])
            print("short", short_period, "long", long_period, "timeframe", timeframe, "average","fixed money", sum(a.profit) / len(a.profit), "all in", sum(b.profit) / len(b.profit))
# Out:
# short 13 long 95 timeframe 12h average fixed money 1.7174279567622497 all in 1.804487990990145
# short 13 long 96 timeframe 12h average fixed money 1.7158436326043365 all in 1.794521345876681
# short 13 long 97 timeframe 12h average fixed money 1.7337809994263038 all in 1.8582845497908815
# short 13 long 98 timeframe 12h average fixed money 1.721156989404295 all in 1.798728219948154
# short 13 long 99 timeframe 12h average fixed money 1.7272946204244723 all in 1.8082008855221667
# short 13 long 100 timeframe 12h average fixed money 1.7080932900879253 all in 1.7815674736871627
# short 13 long 101 timeframe 12h average fixed money 1.7186060176422746 all in 1.8114134333040695
# short 13 long 102 timeframe 12h average fixed money 1.7047330965490501 all in 1.8008225362706252
# short 13 long 103 timeframe 12h average fixed money 1.7077358098344964 all in 1.8009348265473073
# short 13 long 104 timeframe 12h average fixed money 1.7098311856788615 all in 1.7706701604684123
# short 13 long 105 timeframe 12h average fixed money 1.709980091479501 all in 1.762921409254313
# short 13 long 106 timeframe 12h average fixed money 1.707395707199451 all in 1.74334039550519
# short 13 long 107 timeframe 12h average fixed money 1.704279184766979 all in 1.7289978434562534
# short 13 long 108 timeframe 12h average fixed money 1.6991737672313534 all in 1.699759643669449
# short 13 long 109 timeframe 12h average fixed money 1.7054387209939808 all in 1.737989143137237
# short 13 long 110 timeframe 12h average fixed money 1.7183216811459705 all in 1.7962095774737092
# short 14 long 95 timeframe 12h average fixed money 1.7181670780774132 all in 1.7984511464665531
# short 14 long 96 timeframe 12h average fixed money 1.7253400919451372 all in 1.8132504813411092
# short 14 long 97 timeframe 12h average fixed money 1.734669238457439 all in 1.833722259124158
# short 14 long 98 timeframe 12h average fixed money 1.7155444813349334 all in 1.808632241347567
# short 14 long 99 timeframe 12h average fixed money 1.7045264127056508 all in 1.8063647256094613
# short 14 long 100 timeframe 12h average fixed money 1.7008676715179447 all in 1.7987569625640878
# short 14 long 101 timeframe 12h average fixed money 1.711706307951975 all in 1.830770006529707
# short 14 long 102 timeframe 12h average fixed money 1.7108474145308972 all in 1.8229813894805358
# short 14 long 103 timeframe 12h average fixed money 1.7100024117546206 all in 1.7934559661553942
# short 14 long 104 timeframe 12h average fixed money 1.7066989589734503 all in 1.7786063065860251
# short 14 long 105 timeframe 12h average fixed money 1.7075754236160094 all in 1.7715699896651107
# short 14 long 106 timeframe 12h average fixed money 1.7179911995450934 all in 1.7973153767807726
# short 14 long 107 timeframe 12h average fixed money 1.723543478390571 all in 1.8014211756245135
# short 14 long 108 timeframe 12h average fixed money 1.718510598477472 all in 1.7382111452430973
# short 14 long 109 timeframe 12h average fixed money 1.7254207715794727 all in 1.773043113928274
# short 14 long 110 timeframe 12h average fixed money 1.7056681587553641 all in 1.7236983702806925
# short 15 long 95 timeframe 12h average fixed money 1.732712890190672 all in 1.8256421313325122
# short 15 long 96 timeframe 12h average fixed money 1.7280129542810938 all in 1.848302954239116
# short 15 long 97 timeframe 12h average fixed money 1.7000793624796922 all in 1.796387697762857
# short 15 long 98 timeframe 12h average fixed money 1.7209852256355351 all in 1.8740059320886666
# short 15 long 99 timeframe 12h average fixed money 1.7161118826669055 all in 1.8622676874283237
# short 15 long 100 timeframe 12h average fixed money 1.7187038411046949 all in 1.873335810503876
# short 15 long 101 timeframe 12h average fixed money 1.7148993155018 all in 1.853503755467127
# short 15 long 102 timeframe 12h average fixed money 1.7141770940878378 all in 1.8216318223767174
# short 15 long 103 timeframe 12h average fixed money 1.7288166685715078 all in 1.8677793887654321
# short 15 long 104 timeframe 12h average fixed money 1.736519601083724 all in 1.8945923612550934
# short 15 long 105 timeframe 12h average fixed money 1.7348097151390456 all in 1.872270600067736
# short 15 long 106 timeframe 12h average fixed money 1.7305899552397523 all in 1.836821759449591
# short 15 long 107 timeframe 12h average fixed money 1.7152441949057846 all in 1.8084343453409861
# short 15 long 108 timeframe 12h average fixed money 1.74112295073312 all in 1.8864130448314997
# short 15 long 109 timeframe 12h average fixed money 1.7373100478173678 all in 1.8578987593880953
# short 15 long 110 timeframe 12h average fixed money 1.737629867170967 all in 1.9256532056691105
# short 16 long 95 timeframe 12h average fixed money 1.7235324526143354 all in 1.904703923839182
# short 16 long 96 timeframe 12h average fixed money 1.7178482805390665 all in 1.8688292418474168
# short 16 long 97 timeframe 12h average fixed money 1.7179241763288968 all in 1.876916202909188
# short 16 long 98 timeframe 12h average fixed money 1.7140594937864329 all in 1.872934622151609
# short 16 long 99 timeframe 12h average fixed money 1.7213733876499417 all in 1.8935874670156443
# short 16 long 100 timeframe 12h average fixed money 1.7256552961142768 all in 1.8720753181143692
# short 16 long 101 timeframe 12h average fixed money 1.7313257402953905 all in 1.8860239289392366
# short 16 long 102 timeframe 12h average fixed money 1.7303271573076506 all in 1.8664805063496748
# short 16 long 103 timeframe 12h average fixed money 1.7025057549867557 all in 1.7901429481615283
# short 16 long 104 timeframe 12h average fixed money 1.71382730383162 all in 1.799435857821353
# short 16 long 105 timeframe 12h average fixed money 1.7264515830964797 all in 1.8507656377639434
# short 16 long 106 timeframe 12h average fixed money 1.7323894089218799 all in 1.8509768836980083
# short 16 long 107 timeframe 12h average fixed money 1.7258599943987702 all in 1.8657958682768525
# short 16 long 108 timeframe 12h average fixed money 1.7347737173831357 all in 1.9018849516777938
# short 16 long 109 timeframe 12h average fixed money 1.719531015954952 all in 1.8422821616690268
# short 16 long 110 timeframe 12h average fixed money 1.7166092934206065 all in 1.8158119590057409

# %%
a.print()
# Out:
# Time frame 12h
# Start from 1 year ago UTC
# =============
# BTC 1.6655262926894607
# =============
# ETH 1.766749018152799
# =============
# ADA 1.901238481252913
# =============
# BNB 1.5388464649175957
# =============
# average 1.718090064253192
