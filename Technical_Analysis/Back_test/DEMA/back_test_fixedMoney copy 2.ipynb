# %%
import pandas as pd
import numpy as np
from binance.client import Client
import warnings
warnings.simplefilter(action='ignore', category=FutureWarning)
pd.options.mode.chained_assignment = None

# %%
class Strategy():
    def __init__(self, client, symbols, timeframe, startdate = "2 year ago UTC", service_charge = 0.00075, money = 1000, storage = 0):
        self.client = client
        self.symbols = symbols
        self.timeframe = timeframe
        self.startdate = startdate
        self.service_charge = service_charge
        self.start_money = [money] * len(symbols)
        self.start_storage = [storage] * len(symbols)

        self.all_data = []
        for coin in symbols:
            bars = client.get_historical_klines(symbol=f'{coin}USDT',interval=timeframe,start_str=self.startdate)
            test_df = pd.DataFrame(bars[:],columns=["timestamp","open","high","low","close","volume", "close_time", "quote_asset_volume", "number_of_trade", "TBB", "TBQ", "ignore"])
            test_df["date"]=pd.to_datetime(test_df["timestamp"],unit="ms").astype(str)
            test_df = test_df.drop(["timestamp", "close_time", "quote_asset_volume", "number_of_trade", "TBB", "TBQ", "ignore"], axis=1)
            test_df["open"] = pd.to_numeric(test_df["open"])
            test_df["high"] = pd.to_numeric(test_df["high"])
            test_df["low"] = pd.to_numeric(test_df["low"])
            test_df["close"] = pd.to_numeric(test_df["close"])
            test_df["volume"] = pd.to_numeric(test_df["volume"])
            test_df["signal"] = ["None"] * len(test_df)
            self.all_data.append(test_df)

        self.profit = [0] * len(symbols)
    def print(self):
        print("Time frame", self.timeframe)
        print("Start from", self.startdate)

        for i in range(len(self.symbols)):
            print("=============")
            print(self.symbols[i], self.profit[i])

        print("=============")
        print("average", sum(self.profit) / len(self.profit))

    def decide_action(self):
        pass

    def back_test(self, type = "all in", fixed_money = None):
        for i in range(len(self.symbols)):
            money = self.start_money[i]
            storage = self.start_storage[i]
            for j in range(len(self.all_data[i])):
                if (self.all_data[i]["signal"][j] == "buy"):
                    if (type == "all in"):
                        if (storage < 0):
                            money -= -1 * storage * self.all_data[i]["close"][j]
                            storage = 0
                        storage += money / self.all_data[i]["close"][j] 
                        money = 0
                    else:
                        if (storage > 0):
                            money -= -1 * storage * self.all_data[i]["close"][j]
                            storage = 0
                        storage += fixed_money[i] / self.all_data[i]["close"][j] 
                        money -= fixed_money[i]
                elif (self.all_data[i]["signal"][j] == "sell"):
                    if (type == "all in"):
                        if (storage > 0):
                            money += storage * self.all_data[i]["close"][j]
                            storage = 0
                        storage -= money / self.all_data[i]["close"][j] 
                        money += money
                    else:
                        if (storage > 0):
                            money += storage * self.all_data[i]["close"][j]
                            storage = 0
                        storage -= fixed_money[i] / self.all_data[i]["close"][j] 
                        money += fixed_money[i]
            self.profit[i] = (money + storage * self.all_data[i]["close"][len(self.all_data[i]) - 1]) / self.start_money[i]

# %%
class EMA(Strategy):
    def decide_action(self, smooth = 2, short_period = 10, long_period = 100, stable_offset = 150):
        for i in range(len(self.all_data)):
            self.all_data[i]["short EMA"] = self.all_data[i]["close"].copy()
            self.all_data[i]["long EMA"] = self.all_data[i]["close"].copy()

            for j in range(1, len(self.all_data[i])):
                self.all_data[i]["short EMA"][j] = self.all_data[i]["short EMA"][j] * smooth / (short_period + 1) + self.all_data[i]["short EMA"][j - 1] * (1 - smooth / (short_period + 1))
                self.all_data[i]["long EMA"][j] = self.all_data[i]["long EMA"][j] * smooth / (long_period + 1) + self.all_data[i]["long EMA"][j - 1] * (1 - smooth / (long_period + 1))
            for j in range(stable_offset, len(self.all_data[i])):
                if (self.all_data[i]["short EMA"][j - 1] > self.all_data[i]["long EMA"][j - 1] and self.all_data[i]["short EMA"][j - 2] < self.all_data[i]["long EMA"][j - 2]):
                    self.all_data[i]["signal"][j] = "buy"
                elif (self.all_data[i]["short EMA"][j - 1] < self.all_data[i]["long EMA"][j - 1] and self.all_data[i]["short EMA"][j - 2] > self.all_data[i]["long EMA"][j - 2]):
                    self.all_data[i]["signal"][j] = "sell"

# %%
profits = []
count = 0
target_symbol = ["BTC", "ETH", "ADA", "BNB"]
time_frames = ["1d", "12h", "6h", "4h", "2h", "1h"]
time_frames = ["4h"]
start_str = "1 year ago UTC"
client = Client("", "")
res = []
for timeframe in time_frames:
    for short_period in range(13, 17):
        for long_period in range(95,111):
            a = EMA(client, target_symbol, timeframe, start_str)
            b = EMA(client, target_symbol, timeframe, start_str)
            a.decide_action(short_period=short_period, long_period=long_period)
            b.decide_action(short_period=short_period, long_period=long_period)
            a.back_test(type="fixed_money", fixed_money=[1000] * len(target_symbol))
            b.back_test(type="all in", fixed_money=[1000] * len(target_symbol))
            res.append([short_period, long_period, timeframe, sum(a.profit) / len(a.profit)])
            print("short", short_period, "long", long_period, "timeframe", timeframe, "average","fixed money", sum(a.profit) / len(a.profit), "all in", sum(b.profit) / len(b.profit))
# Out:
# short 13 long 95 timeframe 4h average fixed money 1.9774091110902665 all in 1.8868709689739473
# short 13 long 96 timeframe 4h average fixed money 1.9811870634789608 all in 1.921743265845581
# short 13 long 97 timeframe 4h average fixed money 2.00417972328583 all in 2.0132316971622615
# short 13 long 98 timeframe 4h average fixed money 2.006387571899454 all in 2.014504834777912
# short 13 long 99 timeframe 4h average fixed money 2.016115834097354 all in 2.03824587786002
# short 13 long 100 timeframe 4h average fixed money 1.9990675001406846 all in 1.9618243119915402
# short 13 long 101 timeframe 4h average fixed money 1.9850424722912416 all in 1.9290750184766123
# short 13 long 102 timeframe 4h average fixed money 1.9669060953036412 all in 1.8787414633590536
# short 13 long 103 timeframe 4h average fixed money 1.980339346770557 all in 1.9479690615866847
# short 13 long 104 timeframe 4h average fixed money 1.9956834253290001 all in 1.9943265759357454
# short 13 long 105 timeframe 4h average fixed money 2.004011942895264 all in 2.017721775494265
# short 13 long 106 timeframe 4h average fixed money 1.9939846608505785 all in 1.980990745493183
# short 13 long 107 timeframe 4h average fixed money 1.9864356350923618 all in 1.9196187252351768
# short 13 long 108 timeframe 4h average fixed money 1.9790496599372398 all in 1.8981448867998751
# short 13 long 109 timeframe 4h average fixed money 1.9671002775350446 all in 1.7940836920142351
# short 13 long 110 timeframe 4h average fixed money 1.9107673236293718 all in 1.6461767594671832
# short 14 long 95 timeframe 4h average fixed money 1.9998977185812599 all in 1.9952497648173355
# short 14 long 96 timeframe 4h average fixed money 1.9943949474925562 all in 2.005069817632305
# short 14 long 97 timeframe 4h average fixed money 1.999189932681328 all in 2.007721017905928
# short 14 long 98 timeframe 4h average fixed money 2.0017690444605956 all in 2.047878397004138
# short 14 long 99 timeframe 4h average fixed money 1.9867978974318028 all in 2.0106035221065595
# short 14 long 100 timeframe 4h average fixed money 1.9994313215936337 all in 2.042456540056471
# short 14 long 101 timeframe 4h average fixed money 1.9916419471719355 all in 2.0199477340732783
# short 14 long 102 timeframe 4h average fixed money 1.9955638332532215 all in 2.030672227489889
# short 14 long 103 timeframe 4h average fixed money 1.9891533463795406 all in 2.0188689577376615
# short 14 long 104 timeframe 4h average fixed money 1.977029337119484 all in 1.924586449910189
# short 14 long 105 timeframe 4h average fixed money 1.970503336986054 all in 1.8555591416143802
# short 14 long 106 timeframe 4h average fixed money 1.9834830087932018 all in 1.9038770719108473
# short 14 long 107 timeframe 4h average fixed money 1.919427884891634 all in 1.7189396708086166
# short 14 long 108 timeframe 4h average fixed money 1.909949262313014 all in 1.6529757554170668
# short 14 long 109 timeframe 4h average fixed money 1.8971756911159339 all in 1.6085466331739482
# short 14 long 110 timeframe 4h average fixed money 1.901528136148395 all in 1.6276517644427906
# short 15 long 95 timeframe 4h average fixed money 1.9701493643663799 all in 1.9363574755554402
# short 15 long 96 timeframe 4h average fixed money 1.99440197919688 all in 2.000990232784241
# short 15 long 97 timeframe 4h average fixed money 2.006210213567578 all in 2.0351965418808424
# short 15 long 98 timeframe 4h average fixed money 1.9982264221001138 all in 2.0145853899852866
# short 15 long 99 timeframe 4h average fixed money 2.001391109219637 all in 2.0430873103665306
# short 15 long 100 timeframe 4h average fixed money 1.9922189720746843 all in 2.008690522265287
# short 15 long 101 timeframe 4h average fixed money 1.962513406154496 all in 1.8204155363795331
# short 15 long 102 timeframe 4h average fixed money 1.9613377083301449 all in 1.8213932265859407
# short 15 long 103 timeframe 4h average fixed money 1.9049332087129223 all in 1.6805232824028828
# short 15 long 104 timeframe 4h average fixed money 1.904004735943808 all in 1.6593782360963845
# short 15 long 105 timeframe 4h average fixed money 1.907319127791892 all in 1.6504998964915563
# short 15 long 106 timeframe 4h average fixed money 1.9111746903872981 all in 1.642512366126113
# short 15 long 107 timeframe 4h average fixed money 1.8988408355808373 all in 1.6053493989957157
# short 15 long 108 timeframe 4h average fixed money 1.907920918700505 all in 1.6608369333093345
# short 15 long 109 timeframe 4h average fixed money 1.9032055439004005 all in 1.640702979067917
# short 15 long 110 timeframe 4h average fixed money 1.901370818422301 all in 1.6333278731439296
# short 16 long 95 timeframe 4h average fixed money 1.973182639156272 all in 1.8749148942751963
# short 16 long 96 timeframe 4h average fixed money 1.9782512777462875 all in 1.8944053197223862
# short 16 long 97 timeframe 4h average fixed money 1.9767037669630316 all in 1.8332167157149741
# short 16 long 98 timeframe 4h average fixed money 1.9655724199613105 all in 1.7767539461940285
# short 16 long 99 timeframe 4h average fixed money 1.9530846953143037 all in 1.739723053279189
# short 16 long 100 timeframe 4h average fixed money 1.8938304364181078 all in 1.6040474238777134
# short 16 long 101 timeframe 4h average fixed money 1.9018028230671087 all in 1.6430370406898327
# short 16 long 102 timeframe 4h average fixed money 1.890616127810292 all in 1.57969016540884
# short 16 long 103 timeframe 4h average fixed money 1.8836291994610173 all in 1.5315696955301286
# short 16 long 104 timeframe 4h average fixed money 1.8923841286971188 all in 1.5591200818426776
# short 16 long 105 timeframe 4h average fixed money 1.9048291482753141 all in 1.611441285041194
# short 16 long 106 timeframe 4h average fixed money 1.900915835335009 all in 1.596878549819028
# short 16 long 107 timeframe 4h average fixed money 1.8943038856483716 all in 1.5956657500623648
# short 16 long 108 timeframe 4h average fixed money 1.873094913344407 all in 1.606498835210679
# short 16 long 109 timeframe 4h average fixed money 1.9138277443490745 all in 1.6924010194233063
# short 16 long 110 timeframe 4h average fixed money 1.9106518646858794 all in 1.6707150363401633

# %%
a.print()
# Out:
# Time frame 4h
# Start from 1 year ago UTC
# =============
# BTC 1.6081742224918552
# =============
# ETH 1.6146974156193237
# =============
# ADA 2.8022614494269473
# =============
# BNB 1.6174743712053914
# =============
# average 1.9106518646858794
