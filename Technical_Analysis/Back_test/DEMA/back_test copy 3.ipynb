# %%
import pandas as pd
import numpy as np
from binance.client import Client
import warnings
warnings.simplefilter(action='ignore', category=FutureWarning)
pd.options.mode.chained_assignment = None

# %%
class Strategy():
    def __init__(self, client, symbols, timeframe, startdate = "2 year ago UTC", service_charge = 0.00075, money = 1000, storage = 0):
        self.client = client
        self.symbols = symbols
        self.timeframe = timeframe
        self.startdate = startdate
        self.service_charge = service_charge
        self.start_money = [money] * len(symbols)
        self.start_storage = [storage] * len(symbols)

        self.all_data = []
        for coin in symbols:
            bars = client.get_historical_klines(symbol=f'{coin}USDT',interval=timeframe,start_str=self.startdate)
            test_df = pd.DataFrame(bars[:],columns=["timestamp","open","high","low","close","volume", "close_time", "quote_asset_volume", "number_of_trade", "TBB", "TBQ", "ignore"])
            test_df["date"]=pd.to_datetime(test_df["timestamp"],unit="ms").astype(str)
            test_df = test_df.drop(["timestamp", "close_time", "quote_asset_volume", "number_of_trade", "TBB", "TBQ", "ignore"], axis=1)
            test_df["open"] = pd.to_numeric(test_df["open"])
            test_df["high"] = pd.to_numeric(test_df["high"])
            test_df["low"] = pd.to_numeric(test_df["low"])
            test_df["close"] = pd.to_numeric(test_df["close"])
            test_df["volume"] = pd.to_numeric(test_df["volume"])
            test_df["signal"] = ["None"] * len(test_df)
            self.all_data.append(test_df)

        self.profit = [0] * len(symbols)
    def print(self):
        print("Time frame", self.timeframe)
        print("Start from", self.startdate)

        for i in range(len(self.symbols)):
            print("=============")
            print(self.symbols[i], self.profit[i])

        print("=============")
        print("average", sum(self.profit) / len(self.profit))

    def decide_action(self):
        pass

    def back_test(self, type = "all in", fixed_money = None):
        for i in range(len(self.symbols)):
            money = self.start_money[i]
            storage = self.start_storage[i]
            for j in range(len(self.all_data[i])):
                if (self.all_data[i]["signal"][j] == "buy"):
                    if (type == "all in"):
                        if (storage < 0):
                            money -= -1 * storage * self.all_data[i]["close"][j]
                            storage = 0
                        storage += money / self.all_data[i]["close"][j] 
                        money = 0
                    else:
                        if (storage > 0):
                            money -= -1 * storage * self.all_data[i]["close"][j]
                            storage = 0
                        storage += fixed_money[i] / self.all_data[i]["close"][j] 
                        money -= fixed_money[i]
                elif (self.all_data[i]["signal"][j] == "sell"):
                    if (type == "all in"):
                        if (storage > 0):
                            money += storage * self.all_data[i]["close"][j]
                            storage = 0
                        storage -= money / self.all_data[i]["close"][j] 
                        money += money
                    else:
                        if (storage > 0):
                            money += storage * self.all_data[i]["close"][j]
                            storage = 0
                        storage -= fixed_money[i] / self.all_data[i]["close"][j] 
                        money += fixed_money[i]
            self.profit[i] = (money + storage * self.all_data[i]["close"][len(self.all_data[i]) - 1]) / self.start_money[i]

# %%
class EMA(Strategy):
    def decide_action(self, smooth = 2, short_period = 10, long_period = 100, stable_offset = 150):
        for i in range(len(self.all_data)):
            self.all_data[i]["short EMA"] = self.all_data[i]["close"].copy()
            self.all_data[i]["long EMA"] = self.all_data[i]["close"].copy()

            for j in range(1, len(self.all_data[i])):
                self.all_data[i]["short EMA"][j] = self.all_data[i]["short EMA"][j] * smooth / (short_period + 1) + self.all_data[i]["short EMA"][j - 1] * (1 - smooth / (short_period + 1))
                self.all_data[i]["long EMA"][j] = self.all_data[i]["long EMA"][j] * smooth / (long_period + 1) + self.all_data[i]["long EMA"][j - 1] * (1 - smooth / (long_period + 1))
            for j in range(stable_offset, len(self.all_data[i])):
                if (self.all_data[i]["short EMA"][j - 1] > self.all_data[i]["long EMA"][j - 1] and self.all_data[i]["short EMA"][j - 2] < self.all_data[i]["long EMA"][j - 2]):
                    self.all_data[i]["signal"][j] = "buy"
                elif (self.all_data[i]["short EMA"][j - 1] < self.all_data[i]["long EMA"][j - 1] and self.all_data[i]["short EMA"][j - 2] > self.all_data[i]["long EMA"][j - 2]):
                    self.all_data[i]["signal"][j] = "sell"

# %%
profits = []
count = 0
target_symbol = ["BTC", "ETH", "ADA", "BNB"]
time_frames = ["1d", "12h", "6h", "4h", "2h", "1h"]
time_frames = ["4h"]
start_str = "1 year ago UTC"
client = Client("", "")
res = []
for timeframe in time_frames:
    for short_period in range(10, 25):
        for long_period in range(80,120):
            a = EMA(client, target_symbol, timeframe, start_str)
            a.decide_action(short_period=short_period, long_period=long_period)
            a.back_test(type="all in")
            res.append([short_period, long_period, timeframe, sum(a.profit) / len(a.profit)])
            print("short", short_period, "long", long_period, "timeframe", timeframe, "average", sum(a.profit) / len(a.profit))
# Out:
# short 10 long 80 timeframe 4h average 1.5673765647895084
# short 10 long 81 timeframe 4h average 1.5573889375193593
# short 10 long 82 timeframe 4h average 1.6677124859215366
# short 10 long 83 timeframe 4h average 1.6444402044694086
# short 10 long 84 timeframe 4h average 1.6878962839518592
# short 10 long 85 timeframe 4h average 1.5208601218469706
# short 10 long 86 timeframe 4h average 1.5852242144376347
# short 10 long 87 timeframe 4h average 1.664935840247206
# short 10 long 88 timeframe 4h average 1.6980594673957459
# short 10 long 89 timeframe 4h average 1.741988325080933
# short 10 long 90 timeframe 4h average 1.7437410622941971
# short 10 long 91 timeframe 4h average 1.6853383417155423
# short 10 long 92 timeframe 4h average 1.6794522131550627
# short 10 long 93 timeframe 4h average 1.6712238792914798
# short 10 long 94 timeframe 4h average 1.6000757649423158
# short 10 long 95 timeframe 4h average 1.656815840227131
# short 10 long 96 timeframe 4h average 1.8083951054659855
# short 10 long 97 timeframe 4h average 1.6489154826760803
# short 10 long 98 timeframe 4h average 1.702687213093117
# short 10 long 99 timeframe 4h average 1.7129048770074804
# short 10 long 100 timeframe 4h average 1.7351367811572678
# short 10 long 101 timeframe 4h average 1.7481219804754764
# short 10 long 102 timeframe 4h average 1.7638710124625265
# short 10 long 103 timeframe 4h average 1.839972224757509
# short 10 long 104 timeframe 4h average 1.8377319952841347
# short 10 long 105 timeframe 4h average 1.873228257690323
# short 10 long 106 timeframe 4h average 1.8709273031352172
# short 10 long 107 timeframe 4h average 1.8545481790805636
# short 10 long 108 timeframe 4h average 1.8174637890836296
# short 10 long 109 timeframe 4h average 1.801938244170749
# short 10 long 110 timeframe 4h average 1.8228751349601404
# short 10 long 111 timeframe 4h average 1.8277625170101306
# short 22 long 90 timeframe 4h average 1.5429165962322922
# short 22 long 91 timeframe 4h average 1.531653932147376
# short 22 long 92 timeframe 4h average 1.599573009234319
# short 22 long 93 timeframe 4h average 1.5901200219534584
# short 22 long 94 timeframe 4h average 1.5949089850885927
# short 22 long 95 timeframe 4h average 1.5994226698704204
# short 22 long 96 timeframe 4h average 1.5890896227966516
# short 22 long 97 timeframe 4h average 1.5669725504954315
# short 22 long 98 timeframe 4h average 1.4690091204126925
# short 22 long 99 timeframe 4h average 1.5358146150420753
# short 22 long 100 timeframe 4h average 1.5292257075395705
# short 22 long 101 timeframe 4h average 1.5182202628628076
# short 22 long 102 timeframe 4h average 1.5216269594837553
# short 22 long 103 timeframe 4h average 1.5703579418434448
# short 22 long 104 timeframe 4h average 1.653412218543934
# short 22 long 105 timeframe 4h average 1.6583855902682099
# short 22 long 106 timeframe 4h average 1.6368617728541355
# short 22 long 107 timeframe 4h average 1.6626305333608344
# short 22 long 108 timeframe 4h average 1.6450112416137534
# short 22 long 109 timeframe 4h average 1.627427045332992
# short 22 long 110 timeframe 4h average 1.6403890318623926
# short 22 long 111 timeframe 4h average 1.6561075963334475
# short 22 long 112 timeframe 4h average 1.674093626649613
# short 22 long 113 timeframe 4h average 1.6882413343168106
# short 22 long 114 timeframe 4h average 1.7343685027592808
# short 22 long 115 timeframe 4h average 1.7487633819203943
# short 22 long 116 timeframe 4h average 1.7046852308706968
# short 22 long 117 timeframe 4h average 1.69136440440081
# short 22 long 118 timeframe 4h average 1.6824789705251384
# short 22 long 119 timeframe 4h average 1.7606055491437278
# short 23 long 80 timeframe 4h average 1.6980448482841064
# short 23 long 81 timeframe 4h average 1.7391899413151146
# short 23 long 82 timeframe 4h average 1.618676929898852
# short 23 long 83 timeframe 4h average 1.6307729926067491
# short 23 long 84 timeframe 4h average 1.5710288013563585
# short 23 long 85 timeframe 4h average 1.5427184687469235
# short 23 long 86 timeframe 4h average 1.5353923786808452
# short 23 long 87 timeframe 4h average 1.5283983446575065
# short 23 long 88 timeframe 4h average 1.5358725643091378
# short 23 long 89 timeframe 4h average 1.5920417305218528
# short 23 long 90 timeframe 4h average 1.5750020400223657
# short 23 long 91 timeframe 4h average 1.58946454468841
# short 23 long 92 timeframe 4h average 1.578608083982801
# short 23 long 93 timeframe 4h average 1.575091355677111
# short 23 long 94 timeframe 4h average 1.5340326662651291
# short 23 long 95 timeframe 4h average 1.4794892469519605
# short 23 long 96 timeframe 4h average 1.5026025416778275
# short 23 long 97 timeframe 4h average 1.4786523128730995
# short 23 long 98 timeframe 4h average 1.4738284508762411
# short 23 long 99 timeframe 4h average 1.4285685702065547
# short 23 long 100 timeframe 4h average 1.458454555814796
# short 23 long 101 timeframe 4h average 1.5209619666321443
# short 23 long 102 timeframe 4h average 1.5316571501167924
# short 23 long 103 timeframe 4h average 1.5575387606272992
# short 23 long 104 timeframe 4h average 1.586193659366915
# short 23 long 105 timeframe 4h average 1.5709112006019768
# short 23 long 106 timeframe 4h average 1.6204789150170087
# short 23 long 107 timeframe 4h average 1.63252257288835
# short 23 long 108 timeframe 4h average 1.6357959466285217
# short 23 long 109 timeframe 4h average 1.6760391840971565
# short 23 long 110 timeframe 4h average 1.6476753739402337
# short 23 long 111 timeframe 4h average 1.6779435403161171
# short 23 long 112 timeframe 4h average 1.6994983769015555
# short 23 long 113 timeframe 4h average 1.7003229884085873
# short 23 long 114 timeframe 4h average 1.7437731120048867
# short 23 long 115 timeframe 4h average 1.7675718590652245
# short 23 long 116 timeframe 4h average 1.7800206675170194
# short 23 long 117 timeframe 4h average 1.763788456849027
# short 23 long 118 timeframe 4h average 1.7696842266000261
# short 23 long 119 timeframe 4h average 1.887672820976737
# short 24 long 80 timeframe 4h average 1.5981222034306608
# short 24 long 81 timeframe 4h average 1.5504081092077229
# short 24 long 82 timeframe 4h average 1.5898295835376313
# short 24 long 83 timeframe 4h average 1.4961259823265274
# short 24 long 84 timeframe 4h average 1.5010664182097517
# short 24 long 85 timeframe 4h average 1.501871691593107
# short 24 long 86 timeframe 4h average 1.5212214847024832
# short 24 long 87 timeframe 4h average 1.588162787856935
# short 24 long 88 timeframe 4h average 1.6182641453481006
# short 24 long 89 timeframe 4h average 1.5685116696103667
# short 24 long 90 timeframe 4h average 1.5507087970191429
# short 24 long 91 timeframe 4h average 1.5823999386633205
# short 24 long 92 timeframe 4h average 1.5401104176780636
# short 24 long 93 timeframe 4h average 1.5023656761262707
# short 24 long 94 timeframe 4h average 1.4981847676155704
# short 24 long 95 timeframe 4h average 1.5110935719154108
# short 24 long 96 timeframe 4h average 1.4961256514726586
# short 24 long 97 timeframe 4h average 1.5011391390029063
# short 24 long 98 timeframe 4h average 1.52723735949587
# short 24 long 99 timeframe 4h average 1.5396421613658735
# short 24 long 100 timeframe 4h average 1.5650819987257307
# short 24 long 101 timeframe 4h average 1.5784702477759684
# short 24 long 102 timeframe 4h average 1.6286197304411398
# short 24 long 103 timeframe 4h average 1.6224743413221696
# short 24 long 104 timeframe 4h average 1.5837882871371793
# short 24 long 105 timeframe 4h average 1.6074719410398621
# short 24 long 106 timeframe 4h average 1.5774171688078795
# short 24 long 107 timeframe 4h average 1.610579184494475
# short 24 long 108 timeframe 4h average 1.5961035591819404
# short 24 long 109 timeframe 4h average 1.5836926741346589
# short 24 long 110 timeframe 4h average 1.611391016173946
# short 24 long 111 timeframe 4h average 1.7279363198484363
# short 24 long 112 timeframe 4h average 1.7543761302541183
# short 24 long 113 timeframe 4h average 1.736806078935679
# short 24 long 114 timeframe 4h average 1.6969742396390899
# short 24 long 115 timeframe 4h average 1.703456424139593
# short 24 long 116 timeframe 4h average 1.86735323602687
# short 24 long 117 timeframe 4h average 1.9094975374544476
# short 24 long 118 timeframe 4h average 1.8841412770856225
# short 24 long 119 timeframe 4h average 1.8700889372081866

# %%
a.print()
# Out:
# Time frame 4h
# Start from 1 year ago UTC
# =============
# BTC 1.6290099674008087
# =============
# ETH 1.100986755789559
# =============
# ADA 3.167782818968169
# =============
# BNB 1.5825762066742095
# =============
# average 1.8700889372081866
