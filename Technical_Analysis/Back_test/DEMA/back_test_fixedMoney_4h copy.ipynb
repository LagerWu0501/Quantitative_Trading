# %%
import pandas as pd
import numpy as np
from binance.client import Client
import warnings
warnings.simplefilter(action='ignore', category=FutureWarning)
pd.options.mode.chained_assignment = None

# %%
class Strategy():
    def __init__(self, client, symbols, timeframe, startdate = "2 year ago UTC", service_charge = 0.00075, money = 1000, storage = 0):
        self.client = client
        self.symbols = symbols
        self.timeframe = timeframe
        self.startdate = startdate
        self.service_charge = service_charge
        self.start_money = [money] * len(symbols)
        self.start_storage = [storage] * len(symbols)

        self.all_data = []
        for coin in symbols:
            bars = client.get_historical_klines(symbol=f'{coin}USDT',interval=timeframe,start_str=self.startdate)
            test_df = pd.DataFrame(bars[:],columns=["timestamp","open","high","low","close","volume", "close_time", "quote_asset_volume", "number_of_trade", "TBB", "TBQ", "ignore"])
            test_df["date"]=pd.to_datetime(test_df["timestamp"],unit="ms").astype(str)
            test_df = test_df.drop(["timestamp", "close_time", "quote_asset_volume", "number_of_trade", "TBB", "TBQ", "ignore"], axis=1)
            test_df["open"] = pd.to_numeric(test_df["open"])
            test_df["high"] = pd.to_numeric(test_df["high"])
            test_df["low"] = pd.to_numeric(test_df["low"])
            test_df["close"] = pd.to_numeric(test_df["close"])
            test_df["volume"] = pd.to_numeric(test_df["volume"])
            test_df["signal"] = ["None"] * len(test_df)
            self.all_data.append(test_df)

        self.profit = [0] * len(symbols)
    def print(self):
        print("Time frame", self.timeframe)
        print("Start from", self.startdate)

        for i in range(len(self.symbols)):
            print("=============")
            print(self.symbols[i], self.profit[i])

        print("=============")
        print("average", sum(self.profit) / len(self.profit))

    def decide_action(self):
        pass

    def back_test(self, type = "all in", fixed_money = None):
        self.profit = [0] * len(self.symbols)
        for i in range(len(self.symbols)):
            money = self.start_money[i]
            storage = self.start_storage[i]
            for j in range(len(self.all_data[i])):
                if (self.all_data[i]["signal"][j] == "buy"):
                    if (type == "all in"):
                        if (storage < 0):
                            money -= -1 * storage * self.all_data[i]["close"][j]
                            storage = 0
                        storage += money / self.all_data[i]["close"][j] 
                        money = 0
                    else:
                        if (storage > 0):
                            money -= -1 * storage * self.all_data[i]["close"][j]
                            storage = 0
                        storage += fixed_money[i] / self.all_data[i]["close"][j] 
                        money -= fixed_money[i]
                elif (self.all_data[i]["signal"][j] == "sell"):
                    if (type == "all in"):
                        if (storage > 0):
                            money += storage * self.all_data[i]["close"][j]
                            storage = 0
                        storage -= money / self.all_data[i]["close"][j] 
                        money += money
                    else:
                        if (storage > 0):
                            money += storage * self.all_data[i]["close"][j]
                            storage = 0
                        storage -= fixed_money[i] / self.all_data[i]["close"][j] 
                        money += fixed_money[i]
            self.profit[i] = (money + storage * self.all_data[i]["close"][len(self.all_data[i]) - 1]) / self.start_money[i]

# %%
class EMA(Strategy):
    def decide_action(self, smooth = 2, short_period = 10, long_period = 100, stable_offset = 100):
        for i in range(len(self.all_data)):
            self.all_data[i]["short EMA"] = self.all_data[i]["close"].copy()
            self.all_data[i]["long EMA"] = self.all_data[i]["close"].copy()
            self.all_data[i]["signal"] = ["None"] * len(self.all_data[i])

            for j in range(1, len(self.all_data[i])):
                self.all_data[i]["short EMA"][j] = self.all_data[i]["short EMA"][j] * smooth / (short_period + 1) + self.all_data[i]["short EMA"][j - 1] * (1 - smooth / (short_period + 1))
                self.all_data[i]["long EMA"][j] = self.all_data[i]["long EMA"][j] * smooth / (long_period + 1) + self.all_data[i]["long EMA"][j - 1] * (1 - smooth / (long_period + 1))
            for j in range(stable_offset, len(self.all_data[i])):
                if (self.all_data[i]["short EMA"][j - 1] > self.all_data[i]["long EMA"][j - 1] and self.all_data[i]["short EMA"][j - 2] < self.all_data[i]["long EMA"][j - 2]):
                    self.all_data[i]["signal"][j] = "buy"
                elif (self.all_data[i]["short EMA"][j - 1] < self.all_data[i]["long EMA"][j - 1] and self.all_data[i]["short EMA"][j - 2] > self.all_data[i]["long EMA"][j - 2]):
                    self.all_data[i]["signal"][j] = "sell"

# %%
profits = []
count = 0
target_symbol = ["BTC", "ETH", "ADA", "BNB"]
time_frames = ["1d", "12h", "6h", "4h", "2h", "1h"]
time_frames = ["4h"]
start_str = "2021-04-01"
client = Client("YjY0w2BJZZ35o2Q9So1OvRP1gm3exc01LKp2yyLpMth5xmqVn0tQosRYOPrnb7la", "5rRXJ2rOa96hVPZTTOfVP9H4blP6AMt2QN2M0RWX2cMq9PngbJ5MEK88eGB9I4YD")
res = []
for timeframe in time_frames:
    a = EMA(client, target_symbol, timeframe, start_str)
    b = EMA(client, target_symbol, timeframe, start_str)
    for short_period in range(5, 25):
        for long_period in range(55,150):
            a.decide_action(short_period=short_period, long_period=long_period, stable_offset=long_period)
            b.decide_action(short_period=short_period, long_period=long_period, stable_offset=long_period)
            a.back_test(type="fixed_money", fixed_money=[1000] * len(target_symbol))
            b.back_test(type="all in", fixed_money=[1000] * len(target_symbol))
            res.append([short_period, long_period, timeframe, sum(a.profit) / len(a.profit)])
            print("short", short_period, "long", long_period, "timeframe", timeframe, "average","fixed money", sum(a.profit) / len(a.profit), "all in", sum(b.profit) / len(b.profit))
# Out:
# short 5 long 55 timeframe 4h average fixed money 1.6734719651411216 all in 1.5347488849101665
# short 5 long 56 timeframe 4h average fixed money 1.6859386735936694 all in 1.546788813989452
# short 5 long 57 timeframe 4h average fixed money 1.7101501649736306 all in 1.6679208800604342
# short 5 long 58 timeframe 4h average fixed money 1.7232050960340803 all in 1.7152685923176798
# short 5 long 59 timeframe 4h average fixed money 1.6957737255744263 all in 1.6549726030983365
# short 5 long 60 timeframe 4h average fixed money 1.7056691380017581 all in 1.6871617501462302
# short 5 long 61 timeframe 4h average fixed money 1.7146989682405231 all in 1.6563503587985342
# short 5 long 62 timeframe 4h average fixed money 1.7179395127014796 all in 1.6103419213729993
# short 5 long 63 timeframe 4h average fixed money 1.710850819036044 all in 1.5333838106316153
# short 5 long 64 timeframe 4h average fixed money 1.7262185004433919 all in 1.6044642365148112
# short 5 long 65 timeframe 4h average fixed money 1.7356088944688857 all in 1.646875138487508
# short 5 long 66 timeframe 4h average fixed money 1.7301665430985818 all in 1.6294518826130895
# short 5 long 102 timeframe 4h average fixed money 1.732887179936761 all in 1.735268703501354
# short 5 long 103 timeframe 4h average fixed money 1.7366357434554431 all in 1.7270761449296708
# short 5 long 104 timeframe 4h average fixed money 1.6802055854798372 all in 1.5711553759566184
# short 5 long 105 timeframe 4h average fixed money 1.7675672259753614 all in 1.5504813495399987
# short 5 long 106 timeframe 4h average fixed money 1.7852399528109821 all in 1.6161029787851138
# short 5 long 107 timeframe 4h average fixed money 1.7945642305596239 all in 1.665850199767272
# short 5 long 108 timeframe 4h average fixed money 1.8139826683992235 all in 1.7297648279343312
# short 5 long 109 timeframe 4h average fixed money 1.7792900427321172 all in 1.6512239359927037
# short 5 long 110 timeframe 4h average fixed money 1.7939673122753055 all in 1.7018938289606245
# short 5 long 111 timeframe 4h average fixed money 1.7915892337942498 all in 1.6791175353501315
# short 5 long 112 timeframe 4h average fixed money 1.8005401282122389 all in 1.6258038134461326
# short 5 long 113 timeframe 4h average fixed money 1.7819168329925725 all in 1.5606958611220674
# short 5 long 114 timeframe 4h average fixed money 1.767432692352473 all in 1.5735906566815259
# short 5 long 115 timeframe 4h average fixed money 1.786286787661767 all in 1.6891503050293593
# short 5 long 116 timeframe 4h average fixed money 1.8021699878828379 all in 1.7232395293744383
# short 5 long 117 timeframe 4h average fixed money 1.7935357256030622 all in 1.7134479676889844
# short 5 long 118 timeframe 4h average fixed money 1.7720684712641355 all in 1.608261569389404
# short 5 long 119 timeframe 4h average fixed money 1.764653923386976 all in 1.588820795174132
# short 5 long 120 timeframe 4h average fixed money 1.7804143364925185 all in 1.6264818039779987
# short 5 long 121 timeframe 4h average fixed money 1.8197075395064055 all in 1.758019712970294
# short 5 long 122 timeframe 4h average fixed money 1.8381964514569589 all in 1.833535318038527
# short 5 long 123 timeframe 4h average fixed money 1.7661824777042998 all in 1.700587128636926
# short 5 long 124 timeframe 4h average fixed money 1.7474072763636888 all in 1.6810656110821456
# short 5 long 125 timeframe 4h average fixed money 1.7697361113180574 all in 1.7522670562851999
# short 5 long 126 timeframe 4h average fixed money 1.757817744455156 all in 1.7057726755219902
# short 5 long 127 timeframe 4h average fixed money 1.7423257486897403 all in 1.6301162076997369
# short 5 long 128 timeframe 4h average fixed money 1.7491849792161753 all in 1.6455635536020903
# short 5 long 129 timeframe 4h average fixed money 1.7498874322145768 all in 1.6408379232769732
# short 5 long 130 timeframe 4h average fixed money 1.7096763552705228 all in 1.4907869326476235
# short 5 long 131 timeframe 4h average fixed money 1.7321912005132716 all in 1.5663693006762036
# short 5 long 132 timeframe 4h average fixed money 1.728042195679604 all in 1.559162520472197
# short 5 long 133 timeframe 4h average fixed money 1.7235204531679063 all in 1.5315508903831445
# short 5 long 134 timeframe 4h average fixed money 1.7153053286634892 all in 1.4893117518911465
# short 5 long 135 timeframe 4h average fixed money 1.7125189221786776 all in 1.4679438695839733
# short 5 long 136 timeframe 4h average fixed money 1.703886013545727 all in 1.4419672647548143
# short 5 long 137 timeframe 4h average fixed money 1.7138968161012857 all in 1.3072801850405464
# short 7 long 125 timeframe 4h average fixed money 1.8128052226415494 all in 1.6214942208862477
# short 7 long 126 timeframe 4h average fixed money 1.8340014554101511 all in 1.7040702317495313
# short 7 long 127 timeframe 4h average fixed money 1.819712391953702 all in 1.6440445196231324
# short 7 long 128 timeframe 4h average fixed money 1.8189384264907191 all in 1.6169012837105239
# short 7 long 129 timeframe 4h average fixed money 1.8131061181004156 all in 1.5860353580566515
# short 7 long 130 timeframe 4h average fixed money 1.8058346087250448 all in 1.5289072136324204
# short 7 long 131 timeframe 4h average fixed money 1.8123852080889107 all in 1.5395320903545389
# short 7 long 132 timeframe 4h average fixed money 1.818016040151076 all in 1.5823483054490064
# short 7 long 133 timeframe 4h average fixed money 1.8041486239652256 all in 1.5323066841688042
# short 7 long 134 timeframe 4h average fixed money 1.8136769353138313 all in 1.6343397576930971
# short 7 long 135 timeframe 4h average fixed money 1.7885328742056443 all in 1.537151033650689
# short 7 long 136 timeframe 4h average fixed money 1.7998985612961778 all in 1.5657946749198413
# short 7 long 137 timeframe 4h average fixed money 1.812809615507578 all in 1.606184556396699
# short 7 long 138 timeframe 4h average fixed money 1.8178092263520647 all in 1.6420633226677295
# short 7 long 139 timeframe 4h average fixed money 1.814562389054576 all in 1.6318961888946446
# short 7 long 140 timeframe 4h average fixed money 1.797957591216184 all in 1.5689724572006067
# short 7 long 141 timeframe 4h average fixed money 1.8019033189155669 all in 1.563748266943044
# short 7 long 142 timeframe 4h average fixed money 1.8048479654226972 all in 1.5890672674421609
# short 7 long 143 timeframe 4h average fixed money 1.8097170114855738 all in 1.610692698092314
# short 7 long 144 timeframe 4h average fixed money 1.8070169234592126 all in 1.6019220563002776
# short 7 long 145 timeframe 4h average fixed money 1.8088533427385711 all in 1.574384602601866
# short 7 long 146 timeframe 4h average fixed money 1.7935763453591476 all in 1.5334510534224166
# short 7 long 147 timeframe 4h average fixed money 1.7944466717680918 all in 1.550139331043697
# short 7 long 148 timeframe 4h average fixed money 1.7950189839310964 all in 1.57471398557157
# short 7 long 149 timeframe 4h average fixed money 1.7859496381083677 all in 1.5315060422505509
# short 8 long 55 timeframe 4h average fixed money 1.6543363906155464 all in 1.6426990602786704
# short 8 long 56 timeframe 4h average fixed money 1.673940621593345 all in 1.6194822237264734
# short 8 long 57 timeframe 4h average fixed money 1.6517710384625128 all in 1.5290459467544597
# short 8 long 58 timeframe 4h average fixed money 1.6868467239559268 all in 1.6685610156857797
# short 8 long 59 timeframe 4h average fixed money 1.6781536854693746 all in 1.630073072041979
# short 8 long 60 timeframe 4h average fixed money 1.7293465185137995 all in 1.8794815077513876
# short 8 long 61 timeframe 4h average fixed money 1.7068205284518752 all in 1.820275601665689
# short 8 long 62 timeframe 4h average fixed money 1.7150112243053979 all in 1.8488286820235604
# short 8 long 63 timeframe 4h average fixed money 1.7143495431913884 all in 1.856624298854727
# short 8 long 64 timeframe 4h average fixed money 1.701581737810211 all in 1.8262431004490045
# short 8 long 65 timeframe 4h average fixed money 1.6743706640270672 all in 1.7130893532495426
# short 8 long 66 timeframe 4h average fixed money 1.6637418493819678 all in 1.6190050451484808
# short 8 long 67 timeframe 4h average fixed money 1.665835645987615 all in 1.6243047654841427
# short 8 long 68 timeframe 4h average fixed money 1.6795479154689055 all in 1.6948036513328153
# short 8 long 69 timeframe 4h average fixed money 1.6765201679722421 all in 1.658421235269916
# short 8 long 70 timeframe 4h average fixed money 1.6396743552715631 all in 1.510106745202727
# short 8 long 71 timeframe 4h average fixed money 1.65112300001107 all in 1.4675506792236392
# short 8 long 72 timeframe 4h average fixed money 1.643466150706374 all in 1.49362632591575
# short 8 long 73 timeframe 4h average fixed money 1.6300682545326008 all in 1.4577932128168425
# short 8 long 74 timeframe 4h average fixed money 1.6194262560016481 all in 1.3685331053287724
# short 8 long 75 timeframe 4h average fixed money 1.6171786532611627 all in 1.3575370454390625
# short 8 long 76 timeframe 4h average fixed money 1.6069054987114302 all in 1.2824643115782994
# short 8 long 77 timeframe 4h average fixed money 1.635747815329675 all in 1.3824136731102166
# short 8 long 78 timeframe 4h average fixed money 1.654011866787596 all in 1.4709292047649147
# short 8 long 79 timeframe 4h average fixed money 1.6937550326832689 all in 1.6345192512660986
# short 8 long 80 timeframe 4h average fixed money 1.7079235558005763 all in 1.7288348321757636
# short 8 long 81 timeframe 4h average fixed money 1.6961824579880163 all in 1.607696337139268
# short 8 long 82 timeframe 4h average fixed money 1.6764794470444113 all in 1.5746528893027172
# short 8 long 83 timeframe 4h average fixed money 1.6603175467651354 all in 1.5315095150773546
# short 8 long 84 timeframe 4h average fixed money 1.6754479082503668 all in 1.5442802606535013
# short 8 long 85 timeframe 4h average fixed money 1.6756128117741695 all in 1.5504548134094032
# short 8 long 86 timeframe 4h average fixed money 1.68400891229384 all in 1.6284233100881527
# short 8 long 87 timeframe 4h average fixed money 1.6716381472275628 all in 1.54691685416187
# short 8 long 88 timeframe 4h average fixed money 1.6737017345359404 all in 1.6264178889553915
# short 8 long 89 timeframe 4h average fixed money 1.6619276532250096 all in 1.6212479068363663
# short 8 long 90 timeframe 4h average fixed money 1.6572753950539476 all in 1.6066373961445544
# short 8 long 91 timeframe 4h average fixed money 1.647336999740047 all in 1.5267402890692003
# short 8 long 92 timeframe 4h average fixed money 1.6598401666253673 all in 1.5031124116419108
# short 8 long 93 timeframe 4h average fixed money 1.6758856696590478 all in 1.5649527223297415
# short 8 long 94 timeframe 4h average fixed money 1.6861731958311057 all in 1.6286438890791475
# short 8 long 95 timeframe 4h average fixed money 1.658110576794905 all in 1.5211761788731448
# short 8 long 96 timeframe 4h average fixed money 1.6657471440253915 all in 1.492603302356024
# short 8 long 97 timeframe 4h average fixed money 1.6311560174206252 all in 1.4196092317086322
# short 8 long 98 timeframe 4h average fixed money 1.6331474546871172 all in 1.390907747022618
# short 8 long 99 timeframe 4h average fixed money 1.6273751451360279 all in 1.3929755959691708
# short 8 long 100 timeframe 4h average fixed money 1.628665773096892 all in 1.3972716254382636
# short 8 long 101 timeframe 4h average fixed money 1.6351115483677976 all in 1.4060478286086693
# short 8 long 102 timeframe 4h average fixed money 1.6269181475729602 all in 1.3809533341074571
# short 8 long 103 timeframe 4h average fixed money 1.6420645279167045 all in 1.4202500121676347
# short 8 long 104 timeframe 4h average fixed money 1.6394037110420403 all in 1.4217742980388994
# short 8 long 105 timeframe 4h average fixed money 1.6461735763867456 all in 1.532808704568138
# short 8 long 106 timeframe 4h average fixed money 1.7265811010099024 all in 1.6429274744028506
# short 8 long 107 timeframe 4h average fixed money 1.7533869337578751 all in 1.7557491465077812
# short 8 long 108 timeframe 4h average fixed money 1.755987686367212 all in 1.7020074927837123
# short 8 long 109 timeframe 4h average fixed money 1.752004474003227 all in 1.7277921743208602
# short 8 long 110 timeframe 4h average fixed money 1.7484563884082205 all in 1.696510703540366
# short 8 long 111 timeframe 4h average fixed money 1.755869705217392 all in 1.7075062511256516
# short 8 long 112 timeframe 4h average fixed money 1.7480416914702208 all in 1.679738963544711
# short 8 long 113 timeframe 4h average fixed money 1.7499555891658458 all in 1.6810243777049838
# short 8 long 114 timeframe 4h average fixed money 1.7547280700631025 all in 1.6701521227964793
# short 8 long 115 timeframe 4h average fixed money 1.76841847636485 all in 1.7250786592618543
# short 8 long 116 timeframe 4h average fixed money 1.922922660022187 all in 1.8573086808646504
# short 8 long 117 timeframe 4h average fixed money 1.8967962447608941 all in 1.689282426318404
# short 8 long 118 timeframe 4h average fixed money 1.9096499955765682 all in 1.7253352513299314
# short 8 long 119 timeframe 4h average fixed money 1.9014282282230428 all in 1.720316066533842
# short 8 long 120 timeframe 4h average fixed money 1.8089922925764577 all in 1.5761408987908023
# short 8 long 121 timeframe 4h average fixed money 1.7948748169429676 all in 1.5239887357589708
# short 8 long 122 timeframe 4h average fixed money 1.795842840548864 all in 1.5385188297233818
# short 8 long 123 timeframe 4h average fixed money 1.8104630302475142 all in 1.612380156308111
# short 8 long 124 timeframe 4h average fixed money 1.8272107663901132 all in 1.6711100630243685
# short 8 long 125 timeframe 4h average fixed money 1.7911464817529446 all in 1.5389094532492347
# short 8 long 126 timeframe 4h average fixed money 1.7745333893017323 all in 1.4785036710197093
# short 8 long 127 timeframe 4h average fixed money 1.7784374371351772 all in 1.5199526020186664
# short 8 long 128 timeframe 4h average fixed money 1.7723047291714182 all in 1.4788747520468588
# short 8 long 129 timeframe 4h average fixed money 1.7748609201430265 all in 1.4637932242221625
# short 8 long 130 timeframe 4h average fixed money 1.801604816149624 all in 1.5862116140549296
# short 8 long 131 timeframe 4h average fixed money 1.794924799801425 all in 1.597660384702935
# short 8 long 132 timeframe 4h average fixed money 1.8277265102919678 all in 1.7014087491305205
# short 8 long 133 timeframe 4h average fixed money 1.8361571808629726 all in 1.6695684895581284
# short 8 long 134 timeframe 4h average fixed money 1.8321589827033435 all in 1.6630895862744723
# short 8 long 135 timeframe 4h average fixed money 1.8222052752372537 all in 1.6226944050709242
# short 8 long 136 timeframe 4h average fixed money 1.826280522797779 all in 1.6359410516540545
# short 8 long 137 timeframe 4h average fixed money 1.8558433068404026 all in 1.6366531570191518
# short 8 long 138 timeframe 4h average fixed money 1.843738354860832 all in 1.59498672692718
# short 8 long 139 timeframe 4h average fixed money 1.8336826201370555 all in 1.6090381291665243
# short 8 long 140 timeframe 4h average fixed money 1.830049066925428 all in 1.5982612554878801
# short 8 long 141 timeframe 4h average fixed money 1.823375555134866 all in 1.540040544908742
# short 8 long 142 timeframe 4h average fixed money 1.8360660573667564 all in 1.5874182738383757
# short 8 long 143 timeframe 4h average fixed money 1.8303552356416701 all in 1.5756216784456745
# short 8 long 144 timeframe 4h average fixed money 1.836547044799468 all in 1.5956159448453462
# short 8 long 145 timeframe 4h average fixed money 1.839873874469204 all in 1.6029104999795902
# short 8 long 146 timeframe 4h average fixed money 1.83407511442146 all in 1.592392381292052
# short 8 long 147 timeframe 4h average fixed money 1.8297724774658854 all in 1.5638379605829678
# short 8 long 148 timeframe 4h average fixed money 1.8226759801649024 all in 1.5463940029146561
# short 8 long 149 timeframe 4h average fixed money 1.82563281213702 all in 1.54194364337954
# short 9 long 55 timeframe 4h average fixed money 1.6399294092186134 all in 1.599874343603174
# short 9 long 56 timeframe 4h average fixed money 1.67064539228882 all in 1.6235594721484383
# short 9 long 57 timeframe 4h average fixed money 1.6796595499260811 all in 1.6698627482426487
# short 9 long 58 timeframe 4h average fixed money 1.6906066828901396 all in 1.7149522656483007
# short 9 long 59 timeframe 4h average fixed money 1.7017181824819196 all in 1.7504808768312403
# short 9 long 60 timeframe 4h average fixed money 1.7051395777041267 all in 1.807925679257469
# short 9 long 61 timeframe 4h average fixed money 1.7044550851327382 all in 1.7680272921356073
# short 9 long 62 timeframe 4h average fixed money 1.6934896077605086 all in 1.7066837102159984
# short 9 long 63 timeframe 4h average fixed money 1.6717863464635783 all in 1.6966309798649934
# short 9 long 64 timeframe 4h average fixed money 1.702268051071179 all in 1.683663440662394
# short 9 long 65 timeframe 4h average fixed money 1.6996024547659005 all in 1.6905402785997896
# short 9 long 66 timeframe 4h average fixed money 1.6649251464417212 all in 1.6153497826474115
# short 9 long 67 timeframe 4h average fixed money 1.6653546952118634 all in 1.6181643728160766
# short 9 long 68 timeframe 4h average fixed money 1.6310454644084196 all in 1.4231404618491195
# short 9 long 69 timeframe 4h average fixed money 1.6400280344184077 all in 1.474387757739768
# short 9 long 70 timeframe 4h average fixed money 1.632545640371426 all in 1.3975905257132546
# short 9 long 71 timeframe 4h average fixed money 1.6088519400983294 all in 1.3296934888372902
# short 9 long 72 timeframe 4h average fixed money 1.6017759410051073 all in 1.296685302905794
# short 9 long 73 timeframe 4h average fixed money 1.6211072162075217 all in 1.3466774376494548
# short 9 long 74 timeframe 4h average fixed money 1.6219677307032774 all in 1.3611770418878417
# short 9 long 75 timeframe 4h average fixed money 1.656719155410611 all in 1.4489869918768328
# short 9 long 76 timeframe 4h average fixed money 1.6780477821756266 all in 1.5911555569183184
# short 9 long 77 timeframe 4h average fixed money 1.6843887275026153 all in 1.5982563355312038
# short 9 long 78 timeframe 4h average fixed money 1.7030324401021033 all in 1.6745058434329714
# short 9 long 79 timeframe 4h average fixed money 1.7644316270687093 all in 2.0112799753904484
# short 9 long 80 timeframe 4h average fixed money 1.7301939274245344 all in 1.8436123043412886
# short 9 long 81 timeframe 4h average fixed money 1.7179304557002948 all in 1.7915813316272462
# short 9 long 82 timeframe 4h average fixed money 1.6840649979964 all in 1.6222525586881191
# short 9 long 83 timeframe 4h average fixed money 1.6917658593544542 all in 1.609666160677835
# short 9 long 84 timeframe 4h average fixed money 1.6683717417605184 all in 1.525183032056302
# short 9 long 85 timeframe 4h average fixed money 1.6508201826145137 all in 1.5252331112260051
# short 9 long 86 timeframe 4h average fixed money 1.6481767040117796 all in 1.509677650510467
# short 9 long 87 timeframe 4h average fixed money 1.66828883412086 all in 1.478755894938966
# short 9 long 88 timeframe 4h average fixed money 1.6343683172511407 all in 1.3869725428655255
# short 9 long 89 timeframe 4h average fixed money 1.6594697648237908 all in 1.4559292932612817
# short 9 long 90 timeframe 4h average fixed money 1.6397943610866195 all in 1.4157647727385079
# short 9 long 91 timeframe 4h average fixed money 1.6564324927000433 all in 1.4766880267630798
# short 9 long 92 timeframe 4h average fixed money 1.6634888903084764 all in 1.5217415202895694
# short 9 long 93 timeframe 4h average fixed money 1.6408676777587154 all in 1.4613661493042365
# short 9 long 94 timeframe 4h average fixed money 1.6428853894654265 all in 1.455591727729535
# short 9 long 95 timeframe 4h average fixed money 1.635747484161112 all in 1.408464017934137
# short 9 long 96 timeframe 4h average fixed money 1.6425755763234455 all in 1.4090119421099514
# short 9 long 97 timeframe 4h average fixed money 1.6428956965853492 all in 1.404259235194781
# short 9 long 98 timeframe 4h average fixed money 1.6610044708061105 all in 1.5314660289297803
# short 9 long 99 timeframe 4h average fixed money 1.6885676776107774 all in 1.6156814712138703
# short 9 long 100 timeframe 4h average fixed money 1.6782678453328284 all in 1.5942786916192575
# short 9 long 101 timeframe 4h average fixed money 1.6924258153550762 all in 1.6755494854373638
# short 9 long 102 timeframe 4h average fixed money 1.7006899124248707 all in 1.6735411989136209
# short 9 long 103 timeframe 4h average fixed money 1.683168383685045 all in 1.6243684082092538
# short 9 long 104 timeframe 4h average fixed money 1.6883217898746898 all in 1.6468402955414603
# short 9 long 105 timeframe 4h average fixed money 1.7093818266307732 all in 1.7697533045995493
# short 9 long 106 timeframe 4h average fixed money 1.760541491093079 all in 1.7840730172767711
# short 9 long 107 timeframe 4h average fixed money 1.7833564754076823 all in 1.8619911432274923
# short 9 long 108 timeframe 4h average fixed money 1.7886579377610283 all in 1.8414727934713873
# short 9 long 109 timeframe 4h average fixed money 1.780543788687056 all in 1.7759325198735418
# short 9 long 110 timeframe 4h average fixed money 1.775164285265999 all in 1.7878863122707211
# short 9 long 111 timeframe 4h average fixed money 1.7892731262300412 all in 1.8694348917540546
# short 9 long 112 timeframe 4h average fixed money 1.7933096726212754 all in 1.8832741672850235
# short 9 long 113 timeframe 4h average fixed money 1.7824312186716131 all in 1.8181496895829408
# short 9 long 114 timeframe 4h average fixed money 1.7884692635785453 all in 1.8443703526498134
# short 9 long 115 timeframe 4h average fixed money 1.7781585035266778 all in 1.781600152311252
# short 9 long 116 timeframe 4h average fixed money 1.903743534047398 all in 1.6844057221748816
# short 9 long 117 timeframe 4h average fixed money 1.8842770254814756 all in 1.6202691180634017
# short 9 long 118 timeframe 4h average fixed money 1.9011581936783692 all in 1.6672980355423015
# short 9 long 119 timeframe 4h average fixed money 1.8963125819022881 all in 1.6280913670474833
# short 9 long 120 timeframe 4h average fixed money 1.7871712366281778 all in 1.4479850990549452
# short 9 long 121 timeframe 4h average fixed money 1.779330563517032 all in 1.4230932580105171
# short 9 long 122 timeframe 4h average fixed money 1.7887340634429414 all in 1.4726461117357605
# short 9 long 123 timeframe 4h average fixed money 1.7990881042913882 all in 1.5062934774500283
# short 9 long 124 timeframe 4h average fixed money 1.808610244954175 all in 1.5337817095576631
# short 9 long 125 timeframe 4h average fixed money 1.8429480795202489 all in 1.5930410389950975
# short 9 long 126 timeframe 4h average fixed money 1.8162214848064646 all in 1.51527369062793
# short 9 long 127 timeframe 4h average fixed money 1.8236255008876114 all in 1.5135796998031825
# short 9 long 128 timeframe 4h average fixed money 1.8336641531524667 all in 1.5552851999715673
# short 9 long 129 timeframe 4h average fixed money 1.8167482735236835 all in 1.4864202635263162
# short 9 long 130 timeframe 4h average fixed money 1.8273657216104577 all in 1.5185809977313698
# short 9 long 131 timeframe 4h average fixed money 1.8170677778386657 all in 1.447656167250091
# short 9 long 132 timeframe 4h average fixed money 1.8257085460771914 all in 1.4791021356755774
# short 9 long 133 timeframe 4h average fixed money 1.8395245138211547 all in 1.5284022309462433
# short 9 long 134 timeframe 4h average fixed money 1.8312758776438391 all in 1.535772141809758
# short 9 long 135 timeframe 4h average fixed money 1.823877022683683 all in 1.5082586878464206
# short 9 long 136 timeframe 4h average fixed money 1.817536527289874 all in 1.4864590310375863
# short 9 long 137 timeframe 4h average fixed money 1.8264525928724709 all in 1.5075957058983815
# short 9 long 138 timeframe 4h average fixed money 1.8183725357035216 all in 1.4840272107690549
# short 9 long 139 timeframe 4h average fixed money 1.8137403388039903 all in 1.4603293670757649
# short 9 long 140 timeframe 4h average fixed money 1.8263673555068565 all in 1.521664698575547
# short 9 long 141 timeframe 4h average fixed money 1.8153377034776603 all in 1.4896318415657928
# short 9 long 142 timeframe 4h average fixed money 1.8123183239382623 all in 1.4807070318146485
# short 9 long 143 timeframe 4h average fixed money 1.7772180741407462 all in 1.5054608013334558
# short 9 long 144 timeframe 4h average fixed money 1.8009285220565228 all in 1.5437091756123527
# short 9 long 145 timeframe 4h average fixed money 1.7947466315323932 all in 1.5167180235898023
# short 9 long 146 timeframe 4h average fixed money 1.8085915183036863 all in 1.5536182338212376
# short 9 long 147 timeframe 4h average fixed money 1.7890729037855813 all in 1.5235934998629193
# short 9 long 148 timeframe 4h average fixed money 1.8129432623393495 all in 1.6170424864600523
# short 9 long 149 timeframe 4h average fixed money 1.8050662424367385 all in 1.5893775110709814
# short 10 long 55 timeframe 4h average fixed money 1.6445396095956357 all in 1.6569602202901943
# short 10 long 56 timeframe 4h average fixed money 1.6688609137539356 all in 1.7157417020328616
# short 10 long 57 timeframe 4h average fixed money 1.6464709531995987 all in 1.5827719917165752
# short 10 long 58 timeframe 4h average fixed money 1.7012620704245767 all in 1.7349644610262485
# short 10 long 59 timeframe 4h average fixed money 1.706516626625112 all in 1.7865199441369155
# short 10 long 60 timeframe 4h average fixed money 1.7144340243476421 all in 1.8271624794346473
# short 10 long 61 timeframe 4h average fixed money 1.6838049013354845 all in 1.6648440322112403
# short 10 long 62 timeframe 4h average fixed money 1.6601030310589813 all in 1.503542783764669
# short 10 long 63 timeframe 4h average fixed money 1.6433071106564006 all in 1.4413011479062092
# short 10 long 64 timeframe 4h average fixed money 1.6520217080031454 all in 1.4737453959799822
# short 10 long 65 timeframe 4h average fixed money 1.6502542114514547 all in 1.4748076609819323
# short 10 long 66 timeframe 4h average fixed money 1.6396891057774299 all in 1.4056032780180323
# short 10 long 67 timeframe 4h average fixed money 1.6227615830805344 all in 1.3488540719068949
# short 10 long 68 timeframe 4h average fixed money 1.6210494689254378 all in 1.3154224815560331
# short 10 long 69 timeframe 4h average fixed money 1.6178141831996167 all in 1.326974922661204
# short 10 long 70 timeframe 4h average fixed money 1.6235214645054723 all in 1.3618753752301112
# short 10 long 71 timeframe 4h average fixed money 1.6455766040926072 all in 1.445463732398457
# short 10 long 72 timeframe 4h average fixed money 1.6860775811676976 all in 1.586194316709063
# short 10 long 73 timeframe 4h average fixed money 1.7005830384220426 all in 1.7643630741964689
# short 10 long 74 timeframe 4h average fixed money 1.7192735612429297 all in 1.82784891732837
# short 10 long 75 timeframe 4h average fixed money 1.74341875705235 all in 1.9293113113371363
# short 10 long 76 timeframe 4h average fixed money 1.7633026792460824 all in 2.017011772172904
# short 10 long 77 timeframe 4h average fixed money 1.7626776537841782 all in 2.0992827947876265
# short 10 long 78 timeframe 4h average fixed money 1.7216680231100008 all in 1.7828539542635018
# short 10 long 79 timeframe 4h average fixed money 1.70875305548537 all in 1.6926933090307692
# short 10 long 80 timeframe 4h average fixed money 1.7124063265342766 all in 1.6959020876689574
# short 10 long 81 timeframe 4h average fixed money 1.697440582208503 all in 1.7521416621692507
# short 10 long 82 timeframe 4h average fixed money 1.71808417448419 all in 1.7410763946823662
# short 10 long 83 timeframe 4h average fixed money 1.696717052957258 all in 1.6606353473859377
# short 10 long 84 timeframe 4h average fixed money 1.687367212699758 all in 1.6076330740567972
# short 10 long 85 timeframe 4h average fixed money 1.6461156040313607 all in 1.4803868766326604

# %%
a.print()
# Out:
# Time frame 12h
# Start from 2 year ago UTC
# =============
# BTC 1.6487410980418609
# =============
# ETH 1.3965127682638576
# =============
# ADA 0.9646838108525726
# =============
# BNB 1.326264603864199
# =============
# average 1.3340505702556225
