# %%
import pandas as pd
import numpy as np
from binance.client import Client
import warnings
warnings.simplefilter(action='ignore', category=FutureWarning)
pd.options.mode.chained_assignment = None

# %%
from math import floor


class Strategy():
    def __init__(self, client, symbols, timeframe, startdate = "2 year ago UTC", service_charge = 0.00075, money = 1000, storage = 0, save_rate = 0.1):
        self.client = client
        self.symbols = symbols
        self.timeframe = timeframe
        self.startdate = startdate
        self.service_charge = service_charge
        self.start_money = [money] * len(symbols)
        self.start_storage = [storage] * len(symbols)
        self.save_rate = save_rate

        self.all_data = []
        for coin in symbols:
            bars = client.get_historical_klines(symbol=f'{coin}USDT',interval=timeframe,start_str=self.startdate)
            test_df = pd.DataFrame(bars[:],columns=["timestamp","open","high","low","close","volume", "close_time", "quote_asset_volume", "number_of_trade", "TBB", "TBQ", "ignore"])
            test_df["date"]=pd.to_datetime(test_df["timestamp"],unit="ms").astype(str)
            test_df = test_df.drop(["timestamp", "close_time", "quote_asset_volume", "number_of_trade", "TBB", "TBQ", "ignore"], axis=1)
            test_df["open"] = pd.to_numeric(test_df["open"])
            test_df["high"] = pd.to_numeric(test_df["high"])
            test_df["low"] = pd.to_numeric(test_df["low"])
            test_df["close"] = pd.to_numeric(test_df["close"])
            test_df["volume"] = pd.to_numeric(test_df["volume"])
            test_df["signal"] = ["None"] * len(test_df)
            self.all_data.append(test_df)

        self.profit = [0] * len(symbols)
        self.saved_money = [0] * len(symbols)
    def print(self):
        print("Time frame", self.timeframe)
        print("Start from", self.startdate)

        for i in range(len(self.symbols)):
            print("=============")
            print(self.symbols[i], self.profit[i])

        print("=============")
        print("average", sum(self.profit) / len(self.profit))

    def decide_action(self):
        pass

    def back_test(self, type = "all in", fixed_money = None):
        for i in range(len(self.symbols)):
            money = self.start_money[i]
            storage = self.start_storage[i]
            saved_money = 0
            for j in range(len(self.all_data[i])):
                if (self.all_data[i]["signal"][j] == "buy"):
                    if (type == "all in"):
                        if (storage < 0):
                            money -= -1 * storage * self.all_data[i]["close"][j]
                            storage = 0
                        saved_money += floor(self.save_rate * money)
                        money -= floor(self.save_rate * money)
                        
                        storage += money / self.all_data[i]["close"][j] 
                        money = 0
                    else:
                        if (storage > 0):
                            money -= -1 * storage * self.all_data[i]["close"][j]
                            storage = 0
                        storage += fixed_money[i] / self.all_data[i]["close"][j] 
                        money -= fixed_money[i]
                elif (self.all_data[i]["signal"][j] == "sell"):
                    if (type == "all in"):
                        if (storage > 0):
                            money += storage * self.all_data[i]["close"][j]
                            storage = 0
                        saved_money += floor(self.save_rate * money)
                        money -= floor(self.save_rate * money)

                        storage -= money / self.all_data[i]["close"][j] 
                        money += money
                    else:
                        if (storage > 0):
                            money += storage * self.all_data[i]["close"][j]
                            storage = 0
                        storage -= fixed_money[i] / self.all_data[i]["close"][j] 
                        money += fixed_money[i]
            self.profit[i] = (saved_money + money + storage * self.all_data[i]["close"][len(self.all_data[i]) - 1]) / self.start_money[i]
            self.saved_money[i] = saved_money / self.start_money[i]

# %%
class EMA(Strategy):
    def decide_action(self, smooth = 2, short_period = 10, long_period = 100, stable_offset = 150):
        for i in range(len(self.all_data)):
            self.all_data[i]["short EMA"] = self.all_data[i]["close"].copy()
            self.all_data[i]["long EMA"] = self.all_data[i]["close"].copy()
            self.all_data[i]["long SMA"] = self.all_data[i]["close"].copy()

            for j in range(1, len(self.all_data[i])):
                self.all_data[i]["short EMA"][j] = self.all_data[i]["short EMA"][j] * smooth / (short_period + 1) + self.all_data[i]["short EMA"][j - 1] * (1 - smooth / (short_period + 1))
                self.all_data[i]["long EMA"][j] = self.all_data[i]["long EMA"][j] * smooth / (long_period + 1) + self.all_data[i]["long EMA"][j - 1] * (1 - smooth / (long_period + 1))
            # for j in range(long_period, len(self.all_data[i])):
            #     self.all_data[i]["long SMA"][j] = self.all_data[i]["close"][j - long_period:j].mean()
            for j in range(stable_offset, len(self.all_data[i])):
                if (self.all_data[i]["short EMA"][j - 1] > self.all_data[i]["long EMA"][j - 1] and self.all_data[i]["short EMA"][j - 2] < self.all_data[i]["long EMA"][j - 2]):
                # if (self.all_data[i]["close"][j - 1] > self.all_data[i]["long EMA"][j - 1] and self.all_data[i]["close"][j - 2] < self.all_data[i]["long EMA"][j - 2]):
                    self.all_data[i]["signal"][j] = "buy"
                # if (self.all_data[i]["short EMA"][j - 1] > self.all_data[i]["long SMA"][j - 1] and self.all_data[i]["short EMA"][j - 2] < self.all_data[i]["long SMA"][j - 2]):
                #     self.all_data[i]["signal"][j] = "buy"
                elif (self.all_data[i]["short EMA"][j - 1] < self.all_data[i]["long EMA"][j - 1] and self.all_data[i]["short EMA"][j - 2] > self.all_data[i]["long EMA"][j - 2]):
                # elif (self.all_data[i]["close"][j - 1] < self.all_data[i]["long EMA"][j - 1] and self.all_data[i]["close"][j - 2] > self.all_data[i]["long EMA"][j - 2]):
                    self.all_data[i]["signal"][j] = "sell"

# %%
profits = []
count = 0
target_symbol = ["ETH"]
time_frames = ["4h"]
start_str = "2021-7-21"
# start_str = "2017-8-18"
client = Client("", "")
res = []
i = 0
for timeframe in time_frames:
    for long_period in range(120,200):
        for short_period in range(30, 70):
            i += 1
            a = EMA(client, target_symbol, timeframe, start_str, save_rate=0.0)
            b = EMA(client, target_symbol, timeframe, start_str, save_rate=0.0)
            a.decide_action(short_period=short_period, long_period=long_period)
            b.decide_action(short_period=short_period, long_period=long_period)
            a.back_test(type="fixed_money", fixed_money=[1000] * len(target_symbol))
            b.back_test(type="all in", fixed_money=[1000] * len(target_symbol))
            res.append([short_period, long_period, timeframe, sum(a.profit) / len(a.profit)])
            print(i, "short", short_period, "long", long_period, "timeframe", timeframe, "average","fixed money", sum(a.profit) / len(a.profit), "all in", sum(b.profit) / len(b.profit), b.saved_money[0])
# Out:
# 1 short 30 long 120 timeframe 4h average fixed money 1.5952063837182655 all in 1.1975853061415689 0.0
# 2 short 31 long 120 timeframe 4h average fixed money 1.6140661409989325 all in 1.23813614548593 0.0
# 3 short 32 long 120 timeframe 4h average fixed money 1.5878676552040294 all in 1.169485103880363 0.0
# 4 short 33 long 120 timeframe 4h average fixed money 1.589880076824431 all in 1.1821041953585336 0.0
# 5 short 34 long 120 timeframe 4h average fixed money 1.6195576614736624 all in 1.2360072577576802 0.0
# 6 short 35 long 120 timeframe 4h average fixed money 1.6228940615329581 all in 1.2726224895104032 0.0
# 7 short 36 long 120 timeframe 4h average fixed money 1.5527936178380493 all in 1.0530279988524496 0.0
# 8 short 37 long 120 timeframe 4h average fixed money 1.5058280275756848 all in 0.9194542692940894 0.0
# 9 short 38 long 120 timeframe 4h average fixed money 1.508269543099512 all in 0.9267622195568199 0.0
# 10 short 39 long 120 timeframe 4h average fixed money 1.4983807312958783 all in 0.8535304276056332 0.0
# 11 short 40 long 120 timeframe 4h average fixed money 1.5049824971971073 all in 0.8790103053090604 0.0
# 12 short 41 long 120 timeframe 4h average fixed money 1.5050858246185543 all in 0.8772446641923056 0.0
# 13 short 42 long 120 timeframe 4h average fixed money 1.485481390785066 all in 0.8239251155604763 0.0
# 14 short 43 long 120 timeframe 4h average fixed money 1.485393416466275 all in 0.8237758116898194 0.0
# 15 short 44 long 120 timeframe 4h average fixed money 1.4980548531679188 all in 0.8832242772840818 0.0
# 16 short 45 long 120 timeframe 4h average fixed money 1.4985005612089595 all in 0.8699495063122821 0.0
# 17 short 46 long 120 timeframe 4h average fixed money 1.5103344807689187 all in 0.8966534209120284 0.0
# 18 short 47 long 120 timeframe 4h average fixed money 1.5140188737617695 all in 0.9051676488596766 0.0
# 19 short 48 long 120 timeframe 4h average fixed money 1.5220847239591708 all in 0.9662492253035506 0.0
# 20 short 49 long 120 timeframe 4h average fixed money 1.5532064125717984 all in 1.074337407946784 0.0
# 21 short 50 long 120 timeframe 4h average fixed money 1.537589496470285 all in 1.0200293830957206 0.0
# 22 short 51 long 120 timeframe 4h average fixed money 1.5348766068516486 all in 1.0123861799116924 0.0
# 23 short 52 long 120 timeframe 4h average fixed money 1.5285501978417149 all in 0.9882956139417228 0.0
# 24 short 53 long 120 timeframe 4h average fixed money 1.525777452950867 all in 0.9784295499540449 0.0
# 25 short 54 long 120 timeframe 4h average fixed money 1.5507559995340934 all in 1.0412883864688416 0.0
# 26 short 55 long 120 timeframe 4h average fixed money 1.5765186234375514 all in 1.3009603584227125 0.0
# 27 short 56 long 120 timeframe 4h average fixed money 1.596044937602438 all in 1.3892331765638009 0.0
# 28 short 57 long 120 timeframe 4h average fixed money 1.6063205339099271 all in 1.450491767321041 0.0
# 29 short 58 long 120 timeframe 4h average fixed money 1.6005610755715747 all in 1.4205193593722825 0.0
# 30 short 59 long 120 timeframe 4h average fixed money 1.6241789237083581 all in 1.5046483054546906 0.0
# 31 short 60 long 120 timeframe 4h average fixed money 1.6333011977896936 all in 1.5204668773192687 0.0
# 32 short 61 long 120 timeframe 4h average fixed money 1.6359734585676373 all in 1.5547729534986776 0.0
# 33 short 62 long 120 timeframe 4h average fixed money 1.6294026508207597 all in 1.5284682098728957 0.0
# 34 short 63 long 120 timeframe 4h average fixed money 1.6397637826056437 all in 1.549823482804113 0.0
# 35 short 64 long 120 timeframe 4h average fixed money 1.6306096511702712 all in 1.5000269307558134 0.0
# 36 short 65 long 120 timeframe 4h average fixed money 1.6211378929000726 all in 1.4512444378452092 0.0
# 37 short 66 long 120 timeframe 4h average fixed money 1.6344923876055495 all in 1.5015152936634768 0.0
# 38 short 67 long 120 timeframe 4h average fixed money 1.6262301309322424 all in 1.4542492092053552 0.0
# 39 short 68 long 120 timeframe 4h average fixed money 1.659727740628266 all in 1.6182871989316752 0.0
# 40 short 69 long 120 timeframe 4h average fixed money 1.6657547953777552 all in 1.6121572563139297 0.0
# 41 short 30 long 121 timeframe 4h average fixed money 1.593881403085598 all in 1.1946422844170999 0.0
# 42 short 31 long 121 timeframe 4h average fixed money 1.5873200557118163 all in 1.1683322605019857 0.0
# 43 short 32 long 121 timeframe 4h average fixed money 1.5866794676265858 all in 1.1668735607171 0.0
# 44 short 33 long 121 timeframe 4h average fixed money 1.5881786762177335 all in 1.1782205180262348 0.0
# 45 short 34 long 121 timeframe 4h average fixed money 1.617717968561472 all in 1.232206673631699 0.0
# 46 short 35 long 121 timeframe 4h average fixed money 1.621046646772381 all in 1.268282967410439 0.0
# 47 short 36 long 121 timeframe 4h average fixed money 1.512871484596998 all in 0.955996090058044 0.0
# 48 short 37 long 121 timeframe 4h average fixed money 1.5046099742507157 all in 0.9173446369404871 0.0
# 49 short 38 long 121 timeframe 4h average fixed money 1.5092577931321671 all in 0.8990132245475132 0.0
# 50 short 39 long 121 timeframe 4h average fixed money 1.4988697508183288 all in 0.8530670079713389 0.0
# 51 short 40 long 121 timeframe 4h average fixed money 1.503570418140932 all in 0.8765523348859692 0.0
# 52 short 41 long 121 timeframe 4h average fixed money 1.4934151645779086 all in 0.8459870196006751 0.0
# 53 short 42 long 121 timeframe 4h average fixed money 1.4849568031804243 all in 0.8229463457417258 0.0
# 54 short 43 long 121 timeframe 4h average fixed money 1.4779692287951947 all in 0.8080174976546042 0.0
# 55 short 44 long 121 timeframe 4h average fixed money 1.4941620443809958 all in 0.8563524351173532 0.0
# 56 short 45 long 121 timeframe 4h average fixed money 1.5068731437675769 all in 0.8894923249469935 0.0
# 57 short 46 long 121 timeframe 4h average fixed money 1.5209919390256743 all in 0.9375190549335367 0.0
# 58 short 47 long 121 timeframe 4h average fixed money 1.5170762126874289 all in 0.948199866154432 0.0
# 59 short 48 long 121 timeframe 4h average fixed money 1.5238259023274505 all in 0.9704114694013681 0.0
# 60 short 49 long 121 timeframe 4h average fixed money 1.536784797402551 all in 1.0182428120631604 0.0
# 61 short 50 long 121 timeframe 4h average fixed money 1.5281737868261298 all in 0.9893272275490013 0.0
# 62 short 51 long 121 timeframe 4h average fixed money 1.524271927076433 all in 0.9621928926981391 0.0
# 63 short 52 long 121 timeframe 4h average fixed money 1.5288869381951435 all in 0.9844691591351377 0.0
# 64 short 53 long 121 timeframe 4h average fixed money 1.5572918470940513 all in 1.1099708725618014 0.0
# 65 short 54 long 121 timeframe 4h average fixed money 1.5683714095283945 all in 1.2815080221399566 0.0
# 66 short 55 long 121 timeframe 4h average fixed money 1.5887377256969377 all in 1.3612384587887583 0.0
# 67 short 56 long 121 timeframe 4h average fixed money 1.5957859925378584 all in 1.3885432496141095 0.0
# 68 short 57 long 121 timeframe 4h average fixed money 1.6061647226551417 all in 1.4500926547855715 0.0
# 69 short 58 long 121 timeframe 4h average fixed money 1.638169839281672 all in 1.5808941047971001 0.0
# 70 short 59 long 121 timeframe 4h average fixed money 1.633262784939968 all in 1.5203647969370333 0.0
# 71 short 60 long 121 timeframe 4h average fixed money 1.6252368583395196 all in 1.496222022199961 0.0
# 72 short 61 long 121 timeframe 4h average fixed money 1.6298289759620899 all in 1.5293027978068066 0.0
# 73 short 62 long 121 timeframe 4h average fixed money 1.6211959402100125 all in 1.4957674188186403 0.0
# 74 short 63 long 121 timeframe 4h average fixed money 1.6374285283306345 all in 1.537792818513464 0.0
# 75 short 64 long 121 timeframe 4h average fixed money 1.640704561602633 all in 1.5316263709555877 0.0
# 76 short 65 long 121 timeframe 4h average fixed money 1.6415610357195132 all in 1.5280743210212477 0.0
# 77 short 66 long 121 timeframe 4h average fixed money 1.630314323593881 all in 1.462897896699988 0.0
# 78 short 67 long 121 timeframe 4h average fixed money 1.6517925414052697 all in 1.5950451137492518 0.0
# 79 short 68 long 121 timeframe 4h average fixed money 1.6633980435975113 all in 1.6078562113252326 0.0
# 80 short 69 long 121 timeframe 4h average fixed money 1.6528530973725193 all in 1.5920312672980668 0.0
# 81 short 30 long 122 timeframe 4h average fixed money 1.5892510507453408 all in 1.1825281352284835 0.0
# 82 short 31 long 122 timeframe 4h average fixed money 1.586390849748591 all in 1.1662366851040833 0.0
# 83 short 32 long 122 timeframe 4h average fixed money 1.5846850404668589 all in 1.1630132591056481 0.0
# 84 short 33 long 122 timeframe 4h average fixed money 1.6157125212828225 all in 1.2246644125645114 0.0
# 85 short 34 long 122 timeframe 4h average fixed money 1.6122446761687266 all in 1.2301505314847507 0.0
# 86 short 35 long 122 timeframe 4h average fixed money 1.5693183734162583 all in 1.157042753154322 0.0
# 87 short 36 long 122 timeframe 4h average fixed money 1.5119962008383212 all in 0.9543645549149975 0.0
# 88 short 37 long 122 timeframe 4h average fixed money 1.5065614808718073 all in 0.9236477942232945 0.0
# 89 short 38 long 122 timeframe 4h average fixed money 1.5110426060541131 all in 0.9008696485664685 0.0
# 90 short 39 long 122 timeframe 4h average fixed money 1.4971599080475873 all in 0.8485534728269434 0.0
# 91 short 40 long 122 timeframe 4h average fixed money 1.5034635621718295 all in 0.8744270815044851 0.0
# 92 short 41 long 122 timeframe 4h average fixed money 1.4843670494137156 all in 0.8220339331988226 0.0
# 93 short 42 long 122 timeframe 4h average fixed money 1.4844387321919894 all in 0.8221555882045429 0.0
# 94 short 43 long 122 timeframe 4h average fixed money 1.485247049483028 all in 0.8315495272519838 0.0
# 95 short 44 long 122 timeframe 4h average fixed money 1.4933451158773217 all in 0.854936748256347 0.0
# 96 short 45 long 122 timeframe 4h average fixed money 1.5086869919922998 all in 0.893873137547522 0.0
# 97 short 46 long 122 timeframe 4h average fixed money 1.5221490437923682 all in 0.9736325664639803 0.0
# 98 short 47 long 122 timeframe 4h average fixed money 1.5203434138109433 all in 0.9630264924701154 0.0
# 99 short 48 long 122 timeframe 4h average fixed money 1.524587904093337 all in 0.9668996140549455 0.0
# 100 short 49 long 122 timeframe 4h average fixed money 1.5360811367827838 all in 1.0169080176135465 0.0
# 101 short 50 long 122 timeframe 4h average fixed money 1.5373435609434287 all in 1.0138315363911508 0.0
# 102 short 51 long 122 timeframe 4h average fixed money 1.5448774114695514 all in 1.044782600184063 0.0
# 103 short 52 long 122 timeframe 4h average fixed money 1.525083209749284 all in 1.0002515798340172 0.0
# 104 short 53 long 122 timeframe 4h average fixed money 1.5550080977738598 all in 1.2377885202741876 0.0
# 105 short 54 long 122 timeframe 4h average fixed money 1.5748887927369606 all in 1.2974596564926244 0.0
# 106 short 55 long 122 timeframe 4h average fixed money 1.594700708076016 all in 1.3859420385470298 0.0
# 107 short 56 long 122 timeframe 4h average fixed money 1.5935233611879092 all in 1.3816300967848842 0.0
# 108 short 57 long 122 timeframe 4h average fixed money 1.6136664285477664 all in 1.4456960980982194 0.0
# 109 short 58 long 122 timeframe 4h average fixed money 1.6458964234554114 all in 1.5937942227492066 0.0
# 110 short 59 long 122 timeframe 4h average fixed money 1.6317838902255308 all in 1.5164347022209717 0.0
# 111 short 60 long 122 timeframe 4h average fixed money 1.6344617781091204 all in 1.5506383633408298 0.0
# 112 short 61 long 122 timeframe 4h average fixed money 1.6261310576600714 all in 1.5154904107926535 0.0
# 113 short 62 long 122 timeframe 4h average fixed money 1.645149034939615 all in 1.5726168887415968 0.0
# 114 short 63 long 122 timeframe 4h average fixed money 1.6392916925778986 all in 1.5276856414653641 0.0
# 115 short 64 long 122 timeframe 4h average fixed money 1.639206856702961 all in 1.5274718318534923 0.0
# 116 short 65 long 122 timeframe 4h average fixed money 1.6443303320292857 all in 1.5410426519879021 0.0
# 117 short 66 long 122 timeframe 4h average fixed money 1.6511835466965068 all in 1.5932966665267343 0.0
# 118 short 67 long 122 timeframe 4h average fixed money 1.6664158392398702 all in 1.6285833914852017 0.0
# 119 short 68 long 122 timeframe 4h average fixed money 1.6706137523388334 all in 1.6451554202125045 0.0
# 120 short 69 long 122 timeframe 4h average fixed money 1.61947104976745 all in 1.4101080875940821 0.0
# 121 short 30 long 123 timeframe 4h average fixed money 1.595178136604902 all in 1.208413618008921 0.0
# 122 short 31 long 123 timeframe 4h average fixed money 1.5854919600160902 all in 1.1639168454552062 0.0
# 123 short 32 long 123 timeframe 4h average fixed money 1.5826648188251247 all in 1.1563369055079844 0.0
# 124 short 33 long 123 timeframe 4h average fixed money 1.5985167655223413 all in 1.1735214717736469 0.0
# 125 short 34 long 123 timeframe 4h average fixed money 1.6036371543990768 all in 1.2150356232087993 0.0
# 126 short 35 long 123 timeframe 4h average fixed money 1.5269908761000042 all in 1.0156835827231583 0.0
# 127 short 36 long 123 timeframe 4h average fixed money 1.5119858628411713 all in 0.9543452848148828 0.0
# 128 short 37 long 123 timeframe 4h average fixed money 1.5054939551765474 all in 0.8855786397555623 0.0
# 129 short 38 long 123 timeframe 4h average fixed money 1.4987041902646505 all in 0.8532481582181308 0.0
# 130 short 39 long 123 timeframe 4h average fixed money 1.4968254738076607 all in 0.847982659832717 0.0
# 131 short 40 long 123 timeframe 4h average fixed money 1.495230822974084 all in 0.8536767134608629 0.0
# 132 short 41 long 123 timeframe 4h average fixed money 1.484327949716475 all in 0.8219675759229751 0.0
# 133 short 42 long 123 timeframe 4h average fixed money 1.475832127055323 all in 0.799827655695927 0.0
# 134 short 43 long 123 timeframe 4h average fixed money 1.4894265857861946 all in 0.8407000134149025 0.0
# 135 short 44 long 123 timeframe 4h average fixed money 1.5025792770728816 all in 0.8756766679963047 0.0
# 136 short 45 long 123 timeframe 4h average fixed money 1.5247466956596072 all in 0.983309645455263 0.0
# 137 short 46 long 123 timeframe 4h average fixed money 1.5224723928902517 all in 0.974235503912165 0.0
# 138 short 47 long 123 timeframe 4h average fixed money 1.510531658459642 all in 0.9145123744784708 0.0
# 139 short 48 long 123 timeframe 4h average fixed money 1.5272256554024284 all in 0.9735904387080485 0.0
# 140 short 49 long 123 timeframe 4h average fixed money 1.5190736400079001 all in 0.946121916579418 0.0
# 141 short 50 long 123 timeframe 4h average fixed money 1.5333289218417694 all in 0.9978026055173335 0.0
# 142 short 51 long 123 timeframe 4h average fixed money 1.5456739198706786 all in 1.0679886054721681 0.0
# 143 short 52 long 123 timeframe 4h average fixed money 1.5626042890723326 all in 1.1117769161050004 0.0
# 144 short 53 long 123 timeframe 4h average fixed money 1.5670271800019726 all in 1.278468620840436 0.0
# 145 short 54 long 123 timeframe 4h average fixed money 1.587142167137247 all in 1.35740813016377 0.0
# 146 short 55 long 123 timeframe 4h average fixed money 1.5942285141347234 all in 1.3847859447394386 0.0
# 147 short 56 long 123 timeframe 4h average fixed money 1.6060362348041812 all in 1.4056769930423687 0.0
# 148 short 57 long 123 timeframe 4h average fixed money 1.6341142310890742 all in 1.5225031405368818 0.0
# 149 short 58 long 123 timeframe 4h average fixed money 1.652301627531621 all in 1.6193366554805593 0.0
# 150 short 59 long 123 timeframe 4h average fixed money 1.6436402732531923 all in 1.5924768265629852 0.0
# 151 short 60 long 123 timeframe 4h average fixed money 1.6346290465122106 all in 1.5506261063490123 0.0
# 152 short 61 long 123 timeframe 4h average fixed money 1.626222842580255 all in 1.5171553943932994 0.0
# 153 short 62 long 123 timeframe 4h average fixed money 1.642917958983478 all in 1.5532964906816586 0.0
# 154 short 63 long 123 timeframe 4h average fixed money 1.6389028670946117 all in 1.5266285838179188 0.0
# 155 short 64 long 123 timeframe 4h average fixed money 1.6395739816942059 all in 1.5225761010511378 0.0
# 156 short 65 long 123 timeframe 4h average fixed money 1.6247132484061209 all in 1.4502856132618436 0.0
# 157 short 66 long 123 timeframe 4h average fixed money 1.6657734882728024 all in 1.6280757455565504 0.0
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /mnt/c/Users/dm303/OneDrive/Desktop/QT_lab/Quantitative_Trading/Back_test/EMA/ALL_in_90percent_ETH copy 4.ipynb Cell 4 in <cell line: 10>()
#      <a href='vscode-notebook-cell://wsl%2Bubuntu/mnt/c/Users/dm303/OneDrive/Desktop/QT_lab/Quantitative_Trading/Back_test/EMA/ALL_in_90percent_ETH%20copy%204.ipynb#ch0000003vscode-remote?line=13'>14</a> a = EMA(client, target_symbol, timeframe, start_str, save_rate=0.0)
#      <a href='vscode-notebook-cell://wsl%2Bubuntu/mnt/c/Users/dm303/OneDrive/Desktop/QT_lab/Quantitative_Trading/Back_test/EMA/ALL_in_90percent_ETH%20copy%204.ipynb#ch0000003vscode-remote?line=14'>15</a> b = EMA(client, target_symbol, timeframe, start_str, save_rate=0.0)
# ---> <a href='vscode-notebook-cell://wsl%2Bubuntu/mnt/c/Users/dm303/OneDrive/Desktop/QT_lab/Quantitative_Trading/Back_test/EMA/ALL_in_90percent_ETH%20copy%204.ipynb#ch0000003vscode-remote?line=15'>16</a> a.decide_action(short_period=short_period, long_period=long_period)
#      <a href='vscode-notebook-cell://wsl%2Bubuntu/mnt/c/Users/dm303/OneDrive/Desktop/QT_lab/Quantitative_Trading/Back_test/EMA/ALL_in_90percent_ETH%20copy%204.ipynb#ch0000003vscode-remote?line=16'>17</a> b.decide_action(short_period=short_period, long_period=long_period)
#      <a href='vscode-notebook-cell://wsl%2Bubuntu/mnt/c/Users/dm303/OneDrive/Desktop/QT_lab/Quantitative_Trading/Back_test/EMA/ALL_in_90percent_ETH%20copy%204.ipynb#ch0000003vscode-remote?line=17'>18</a> a.back_test(type="fixed_money", fixed_money=[1000] * len(target_symbol))
#
# /mnt/c/Users/dm303/OneDrive/Desktop/QT_lab/Quantitative_Trading/Back_test/EMA/ALL_in_90percent_ETH copy 4.ipynb Cell 4 in EMA.decide_action(self, smooth, short_period, long_period, stable_offset)
#       <a href='vscode-notebook-cell://wsl%2Bubuntu/mnt/c/Users/dm303/OneDrive/Desktop/QT_lab/Quantitative_Trading/Back_test/EMA/ALL_in_90percent_ETH%20copy%204.ipynb#ch0000003vscode-remote?line=7'>8</a> for j in range(1, len(self.all_data[i])):
#       <a href='vscode-notebook-cell://wsl%2Bubuntu/mnt/c/Users/dm303/OneDrive/Desktop/QT_lab/Quantitative_Trading/Back_test/EMA/ALL_in_90percent_ETH%20copy%204.ipynb#ch0000003vscode-remote?line=8'>9</a>     self.all_data[i]["short EMA"][j] = self.all_data[i]["short EMA"][j] * smooth / (short_period + 1) + self.all_data[i]["short EMA"][j - 1] * (1 - smooth / (short_period + 1))
# ---> <a href='vscode-notebook-cell://wsl%2Bubuntu/mnt/c/Users/dm303/OneDrive/Desktop/QT_lab/Quantitative_Trading/Back_test/EMA/ALL_in_90percent_ETH%20copy%204.ipynb#ch0000003vscode-remote?line=9'>10</a>     self.all_data[i]["long EMA"][j] = self.all_data[i]["long EMA"][j] * smooth / (long_period + 1) + self.all_data[i]["long EMA"][j - 1] * (1 - smooth / (long_period + 1))
#      <a href='vscode-notebook-cell://wsl%2Bubuntu/mnt/c/Users/dm303/OneDrive/Desktop/QT_lab/Quantitative_Trading/Back_test/EMA/ALL_in_90percent_ETH%20copy%204.ipynb#ch0000003vscode-remote?line=10'>11</a> # for j in range(long_period, len(self.all_data[i])):
#      <a href='vscode-notebook-cell://wsl%2Bubuntu/mnt/c/Users/dm303/OneDrive/Desktop/QT_lab/Quantitative_Trading/Back_test/EMA/ALL_in_90percent_ETH%20copy%204.ipynb#ch0000003vscode-remote?line=11'>12</a> #     self.all_data[i]["long SMA"][j] = self.all_data[i]["close"][j - long_period:j].mean()
#      <a href='vscode-notebook-cell://wsl%2Bubuntu/mnt/c/Users/dm303/OneDrive/Desktop/QT_lab/Quantitative_Trading/Back_test/EMA/ALL_in_90percent_ETH%20copy%204.ipynb#ch0000003vscode-remote?line=12'>13</a> for j in range(stable_offset, len(self.all_data[i])):
#
# File ~/.local/lib/python3.10/site-packages/pandas/core/series.py:1143, in Series.__setitem__(self, key, value)
#    1140         self._set_with(key, value)
#    1142 if cacher_needs_updating:
# -> 1143     self._maybe_update_cacher()
#
# File ~/.local/lib/python3.10/site-packages/pandas/core/series.py:1279, in Series._maybe_update_cacher(self, clear, verify_is_copy, inplace)
#    1274     del self._cacher
#    1275 elif len(self) == len(ref) and self.name in ref.columns:
#    1276     # GH#42530 self.name must be in ref.columns
#    1277     # to ensure column still in dataframe
#    1278     # otherwise, either self or ref has swapped in new arrays
# -> 1279     ref._maybe_cache_changed(cacher[0], self, inplace=inplace)
#    1280 else:
#    1281     # GH#33675 we have swapped in a new array, so parent
#    1282     #  reference to self is now invalid
#    1283     ref._item_cache.pop(cacher[0], None)
#
# File ~/.local/lib/python3.10/site-packages/pandas/core/frame.py:3956, in DataFrame._maybe_cache_changed(self, item, value, inplace)
#    3952 if old._values is value._values and inplace:
#    3953     # GH#46149 avoid making unnecessary copies/block-splitting
#    3954     return
# -> 3956 self._mgr.iset(loc, arraylike, inplace=inplace)
#
# File ~/.local/lib/python3.10/site-packages/pandas/core/internals/managers.py:1075, in BlockManager.iset(self, loc, value, inplace)
#    1072     self._rebuild_blknos_and_blklocs()
#    1074 # Note: we exclude DTA/TDA here
# -> 1075 value_is_extension_type = is_1d_only_ea_dtype(value.dtype)
#    1076 if not value_is_extension_type:
#    1077     if value.ndim == 2:
#
# File ~/.local/lib/python3.10/site-packages/pandas/core/dtypes/common.py:1424, in is_1d_only_ea_dtype(dtype)
#    1417 """
#    1418 Analogue to is_extension_array_dtype but excluding DatetimeTZDtype.
#    1419 """
#    1420 # Note: if other EA dtypes are ever held in HybridBlock, exclude those
#    1421 #  here too.
#    1422 # NB: need to check DatetimeTZDtype and not is_datetime64tz_dtype
#    1423 #  to exclude ArrowTimestampUSDtype
# -> 1424 return isinstance(dtype, ExtensionDtype) and not isinstance(
#    1425     dtype, (DatetimeTZDtype, PeriodDtype)
#    1426 )
#
# KeyboardInterrupt:
