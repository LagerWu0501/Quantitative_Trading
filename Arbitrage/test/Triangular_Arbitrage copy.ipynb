# %%
import pandas as pd
import numpy as np
from binance.client import Client
from huobi.linear_swap.rest.account import Account
from huobi.linear_swap.rest.market import Market
from huobi.linear_swap.rest.order import Order
import ftx
from pybit import spot
import pybit

import os
import sys

# %%
client = Client()

# %%
symbols = ["ETHUSDT", "ETHBTC", "BTCUSDT"]
FTX_maker_charge = 0.001
unit = 100

BTC_Storage = 0
ETH_Storage = 0
USDT_Storage = 100
i = 0
while True:
    FTX_orders = client.get_order_book(symbol=symbols[0])
    FTX_orders = client.get_order_book(symbol=symbols[0])
    FTX_orders = client.get_order_book(symbol=symbols[0])
    i += 1
    if (i == 1200):
        break
# Out:
# {'lastUpdateId': 19048122412, 'bids': [['1631.88000000', '3.45580000'], ['1631.82000000', '4.35000000'], ['1631.81000000', '0.01000000'], ['1631.73000000', '0.15000000'], ['1631.66000000', '0.01020000'], ['1631.65000000', '1.23290000'], ['1631.64000000', '3.06370000'], ['1631.62000000', '0.00680000'], ['1631.59000000', '4.03160000'], ['1631.55000000', '0.02000000'], ['1631.54000000', '17.06480000'], ['1631.53000000', '7.20650000'], ['1631.52000000', '2.45100000'], ['1631.50000000', '2.91120000'], ['1631.49000000', '31.16830000'], ['1631.48000000', '4.88540000'], ['1631.47000000', '21.35240000'], ['1631.46000000', '0.02600000'], ['1631.44000000', '7.59290000'], ['1631.42000000', '7.06880000'], ['1631.37000000', '5.84600000'], ['1631.36000000', '7.96290000'], ['1631.34000000', '30.50000000'], ['1631.33000000', '4.59590000'], ['1631.31000000', '0.00680000'], ['1631.30000000', '0.20000000'], ['1631.23000000', '11.05320000'], ['1631.19000000', '1.50700000'], ['1631.18000000', '2.91140000'
# ...
